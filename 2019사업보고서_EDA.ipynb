# %% [markdown]
# ### 1.data load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

#  data load
df2019 = pd.read_csv("./data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

# %%
df2019[df2019["회사명"] == "레드로버"]
# Out:
#            종목코드   회사명       시장구분   업종                        업종명  결산월  \
# 22484  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22485  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22486  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22487  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22488  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22489  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22490  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22491  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22492  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22493  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22494  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22495  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22496  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22497  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22498  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22499  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22500  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22501  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22502  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22503  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22504  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22505  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22506  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22507  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22508  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22509  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22510  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22511  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22512  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22513  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22514  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22515  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22516  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22517  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22518  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22519  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22520  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22521  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22522  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22523  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22524  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
# 22525  [060300]  레드로버  코스닥시장상장법인  591  영화, 비디오물, 방송프로그램 제작 및 배급업   12
#
#             결산기준일  보고서종류                                               항목코드  \
# 22484  2019-12-31  사업보고서                           ifrs-full_AssetsAbstract
# 22485  2019-12-31  사업보고서                            ifrs-full_CurrentAssets
# 22486  2019-12-31  사업보고서                   ifrs-full_CashAndCashEquivalents
# 22487  2019-12-31  사업보고서          ifrs-full_TradeAndOtherCurrentReceivables
# 22488  2019-12-31  사업보고서              ifrs-full_OtherCurrentFinancialAssets
# 22489  2019-12-31  사업보고서                         ifrs-full_CurrentTaxAssets
# 22490  2019-12-31  사업보고서                              ifrs-full_Inventories
# 22491  2019-12-31  사업보고서                            dart_OtherCurrentAssets
# 22492  2019-12-31  사업보고서                         ifrs-full_NoncurrentAssets
# 22493  2019-12-31  사업보고서     dart_NonCurrentAvailableForSaleFinancialAssets
# 22494  2019-12-31  사업보고서  ifrs-full_NoncurrentFinancialAssetsMeasuredAtF...
# 22495  2019-12-31  사업보고서  ifrs-full_InvestmentsInSubsidiariesJointVentur...
# 22496  2019-12-31  사업보고서                ifrs-full_InvestmentsInSubsidiaries
# 22497  2019-12-31  사업보고서           ifrs-full_OtherNoncurrentFinancialAssets
# 22498  2019-12-31  사업보고서                ifrs-full_PropertyPlantAndEquipment
# 22499  2019-12-31  사업보고서                    dart_OtherIntangibleAssetsGross
# 22500  2019-12-31  사업보고서                        ifrs-full_DeferredTaxAssets
# 22501  2019-12-31  사업보고서                                   ifrs-full_Assets
# 22502  2019-12-31  사업보고서                      ifrs-full_LiabilitiesAbstract
# 22503  2019-12-31  사업보고서                       ifrs-full_CurrentLiabilities
# 22504  2019-12-31  사업보고서             ifrs-full_TradeAndOtherCurrentPayables
# 22505  2019-12-31  사업보고서                      ifrs-full_ShorttermBorrowings
# 22506  2019-12-31  사업보고서        dart_CurentPortionOfFinanceLeaseLiabilities
# 22507  2019-12-31  사업보고서                  dart_CurrentDerivativeLiabilities
# 22508  2019-12-31  사업보고서                       dart_OtherCurrentLiabilities
# 22509  2019-12-31  사업보고서                    ifrs-full_NoncurrentLiabilities
# 22510  2019-12-31  사업보고서  entity00364795_udf_BS_2020320142053885_Noncurr...
# 22511  2019-12-31  사업보고서                       dart_LongTermBorrowingsGross
# 22512  2019-12-31  사업보고서       dart_LongTermTradeAndOtherNonCurrentPayables
# 22513  2019-12-31  사업보고서                              dart_ConvertibleBonds
# 22514  2019-12-31  사업보고서      ifrs-full_OtherNoncurrentFinancialLiabilities
# 22515  2019-12-31  사업보고서                   ifrs-full_DeferredTaxLiabilities
# 22516  2019-12-31  사업보고서                              ifrs-full_Liabilities
# 22517  2019-12-31  사업보고서                           ifrs-full_EquityAbstract
# 22518  2019-12-31  사업보고서       ifrs-full_EquityAttributableToOwnersOfParent
# 22519  2019-12-31  사업보고서                            ifrs-full_IssuedCapital
# 22520  2019-12-31  사업보고서                             ifrs-full_SharePremium
# 22521  2019-12-31  사업보고서                           ifrs-full_TreasuryShares
# 22522  2019-12-31  사업보고서                         ifrs-full_RetainedEarnings
# 22523  2019-12-31  사업보고서             dart_ElementsOfOtherStockholdersEquity
# 22524  2019-12-31  사업보고서  dart_OtherComprehensiveIncomeLossAccumulatedAm...
# 22525  2019-12-31  사업보고서                                   ifrs-full_Equity
#
#                               항목명            당기
# 22484               자산 [abstract]           NaN
# 22485                        유동자산  9.473623e+09
# 22486                    현금및현금성자산  9.551862e+07
# 22487               매출채권 및 기타유동채권  8.643018e+09
# 22488                    기타유동금융자산           NaN
# 22489                     당기법인세자산  1.763072e+07
# 22490                        재고자산  1.000394e+08
# 22491                      기타유동자산  6.174157e+08
# 22492                       비유동자산  1.856741e+10
# 22493                 비유동매도가능금융자산           NaN
# 22494     비유동 기타포괄손익-공정가치 측정 금융자산  8.396363e+09
# 22495  종속기업, 조인트벤처와 관계기업에 대한 투자자산  3.149387e+09
# 22496               종속기업에 대한 투자자산           NaN
# 22497                   기타비유동금융자산  5.672876e+09
# 22498                        유형자산  1.018223e+09
# 22499                      기타무형자산  3.305655e+08
# 22500                     이연법인세자산           NaN
# 22501                        자산총계  2.804104e+10
# 22502               부채 [abstract]           NaN
# 22503                        유동부채  2.049342e+10
# 22504               매입채무 및 기타유동채무  7.568447e+09
# 22505                       단기차입금  5.356603e+09
# 22506                   유동성금융리스부채  1.594892e+09
# 22507                    유동파생상품부채  5.845006e+09
# 22508                      기타유동부채  1.284714e+08
# 22509                       비유동부채  1.758428e+09
# 22510                 매입채무 및 기타채무           NaN
# 22511                       장기차입금           NaN
# 22512            장기매입채무 및 기타비유동채무  2.974140e+08
# 22513                        전환사채  1.411414e+09
# 22514                   기타비유동금융부채  4.960000e+07
# 22515                     이연법인세부채           NaN
# 22516                        부채총계  2.225185e+10
# 22517               자본 [abstract]           NaN
# 22518         지배기업의 소유주에게 귀속되는 자본  5.789188e+09
# 22519                         자본금  2.781885e+10
# 22520                     주식발행초과금  1.584608e+11
# 22521                        자기주식           NaN
# 22522                  이익잉여금(결손금) -1.721994e+11
# 22523                    기타자본구성요소 -8.096135e+09
# 22524                   기타포괄손익누계액 -1.949113e+08
# 22525                        자본총계  5.789188e+09

# %% [markdown]
# ### 2. 불필요한 변수 제거

# %%
# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("전기", axis = 1, inplace = True)
    data.drop("전전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df2019 = delete_col(df2019)

# %% [markdown]
# ### 3. 연속형변수(당기, 전기, 전전기)  dtype 변경

# %%
def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
#     data["전기"] = data["전기"].str.replace(",", "")
#     data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    return data

df2019 = str_to_float(df2019)

# %% [markdown]
# ### 4. 항목명 변수 처리

# %%
def duplication_check(data):
    # 항목코드 중복 확인
    entity_코드 = []
    entity_명 = []
    without_entity_코드 = []
    without_entity_명 = []

    # 각 리스트에 코드 및 코드명 append(소문자 처리)
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            entity_코드.append(data["항목코드"][idx].lower())
            entity_명.append(data["항목명"][idx].lower())
        else:
            without_entity_코드.append(data["항목코드"][idx].lower())
            without_entity_명.append(data["항목명"][idx].lower())

    # !entity 코드 딕셔너리
    dic_without_entity = {re.findall("_\w{1,}", without_entity_코드[idx])[0].lower():[] for idx in range(len(without_entity_코드))}

    for i, j in zip(without_entity_코드, without_entity_명):
        dic_without_entity[re.findall("_\w{1,}", i)[0].lower()].append(j)

    check_without_entity = {i:len(set(j)) for i, j in dic_without_entity.items()}
    
    # entity 코드 딕셔너리
    dic_entity = {entity_코드[idx]:[] for idx in range(len(entity_코드))}
    
    for i, j in zip(entity_코드, entity_명):
        dic_entity[i].append(j)
        
    check_entity = {i:len(set(j)) for i, j in dic_entity.items()}
    
    return entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity

entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity = duplication_check(df2019)

# %% [markdown]
# ### 5. 공시된 항목명, 항목코드 가져오기(금융감독원 재무제표 양식)

# %%
def extract_element_id(data):
    element_idx_lst_entity = []
    element_idx_lst_without_entity = []
    
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            element_idx_lst_entity.append(data["항목코드"][idx])
        else:
            element_idx_lst_without_entity.append(data["항목코드"][idx])
            
    entity = sorted(set(element_idx_lst_entity), reverse = True)
    without_entity = sorted(set(element_idx_lst_without_entity), reverse = True)
    
    return entity, without_entity

a, b = extract_element_id(df2019)
pd.Series(b).to_csv("./2019항목명.csv", encoding = "euc-kr", index = False)

elementid = pd.read_excel("./data/재무제표양식.xlsx", encoding = "utf-8", sheet_name = "BS1")
# '한글 Label', 'Element ID'
df_element = elementid[['한글 Label', 'Element ID']]
df_element = df_element[df_element["Element ID"].notnull()]

df_element.columns = df_element.columns.str.replace(" ", "_")
lst_element = df_element["Element_ID"].unique()

re_lst_element = []
for i in lst_element:
    a = re.findall("_\w{1,}", i)[0].lower()
    re_lst_element.append(a)
 
dic_element = {i:[] for i in re_lst_element}
for i, j in zip(re_lst_element, df_element["한글_Label"]):
    dic_element[i].append(j)

# %% [markdown]
# ### 5-1. 항목명 entity 값 처리

# %%
lst_idx = []
for i in range(len(df2019)):
    if "총계" in df2019["항목명"][i] and "entity" in df2019["항목코드"][i]:
        lst_idx.append(i)

# %%
# 처리 대상 항목명 추출
set(df2019[["항목코드", "항목명"]].iloc[lst_idx,]["항목명"])
# '   자본의 총계', '자본총계'
# '부채총계'
# '자본과 부채의 총계'
# '자산총계'

# %%
for i in lst_idx:
    if df2019["항목명"][i] == '부채총계':
        df2019["항목코드"][i] = "ifrs-full_Liabilities"
        
    elif df2019["항목명"][i] == '자본과 부채의 총계':
        df2019["항목코드"][i] = "ifrs-full_EquityAndLiabilities"
        
    elif df2019["항목명"][i] == '자산총계':
        df2019["항목코드"][i] = "ifrs-full_Assets"
        
    else:
        df2019["항목코드"][i] = "ifrs-full_Equity"

# %% [markdown]
# ### 6. entity 제외 항목명 변수 전처리

# %%
for idx in range(len(df2019)):
    if "entity" not in df2019["항목코드"][idx]:
        df2019["항목명"][idx] = dic_element[re.findall("_\w{1,}", df2019["항목코드"][idx])[0].lower()][0]
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### 7. 정제된 데이터 프레임 만들기

# %%
# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df2019["회사명"].unique()
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df2019.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df2019[df2019["회사명"] == i]["결산기준일"].unique())
    day.append(len(df2019[df2019["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
last_df = pd.DataFrame(bon, columns = col)

# %% [markdown]
# ### 8. 데이터 입력

# %%
dic_standard = {i:list(df2019[df2019["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df2019[(df2019["회사명"] == last_company[idx]) & (df2019["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        last_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = dic_element[re.findall("_\w{1,}", a["항목코드"][idx3])[0].lower()][0]
            last_df.loc[cnt, loc] = a["당기"][idx3]
    cnt += 1

# %% [markdown]
# ### 9. 2018데이터 입력

# %%
# 2018년 변수 처리
df = pd.read_csv("./data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
    data["전기"] = data["전기"].str.replace(",", "")
    data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    data["전기"] = data["전기"].astype(np.float32)
    data["전전기"] = data["전전기"].astype(np.float32)
    return data

df = str_to_float(df)

# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("당기", axis = 1, inplace = True)
    data.drop("전전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df = delete_col(df)


# 항목명 변수 전처리
lst_idx = []
for i in range(len(df)):
    if "총계" in df["항목명"][i] and "entity" in df["항목코드"][i]:
        lst_idx.append(i)


for i in lst_idx:
    if df["항목명"][i] == '부채총계':
        df["항목코드"][i] = "ifrs-full_Liabilities"
        
    elif df["항목명"][i] == '자본과 부채의 총계':
        df["항목코드"][i] = "ifrs-full_EquityAndLiabilities"
        
    elif df["항목명"][i] == '자산총계':
        df["항목코드"][i] = "ifrs-full_Assets"
        
    else:
        df["항목코드"][i] = "ifrs-full_Equity"
        
        
for idx in range(len(df)):
    if "entity" not in df["항목코드"][idx]:
        df["항목명"][idx] = dic_element[re.findall("_\w{1,}", df["항목코드"][idx])[0].lower()][0]




# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df["회사명"].unique()
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df[df["회사명"] == i]["결산기준일"].unique())
    day.append(len(df[df["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
add_df = pd.DataFrame(bon, columns = col)


# 정제된 데이터프레임 생성
dic_standard = {i:list(df[df["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df[(df["회사명"] == last_company[idx]) & (df["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        add_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = dic_element[re.findall("_\w{1,}", a["항목코드"][idx3])[0].lower()][0]
            add_df.loc[cnt, loc] = a["전기"][idx3]
    cnt += 1

add_df["결산기준일"] = add_df["결산기준일"].str.replace("2019", "2018")

last_df = pd.concat([last_df, add_df]).reset_index(drop = True)

# %% [markdown]
# ### 10. 2017 데이터 입력

# %%
# 2017년 변수 처리
df = pd.read_csv("./data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
    data["전기"] = data["전기"].str.replace(",", "")
    data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    data["전기"] = data["전기"].astype(np.float32)
    data["전전기"] = data["전전기"].astype(np.float32)
    return data

df = str_to_float(df)

# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("당기", axis = 1, inplace = True)
    data.drop("전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df = delete_col(df)

# 항목명 변수 전처리
lst_idx = []
for i in range(len(df)):
    if "총계" in df["항목명"][i] and "entity" in df["항목코드"][i]:
        lst_idx.append(i)


for i in lst_idx:
    if df["항목명"][i] == '부채총계':
        df["항목코드"][i] = "ifrs-full_Liabilities"
        
    elif df["항목명"][i] == '자본과 부채의 총계':
        df["항목코드"][i] = "ifrs-full_EquityAndLiabilities"
        
    elif df["항목명"][i] == '자산총계':
        df["항목코드"][i] = "ifrs-full_Assets"
        
    else:
        df["항목코드"][i] = "ifrs-full_Equity"
        
        
for idx in range(len(df)):
    if "entity" not in df["항목코드"][idx]:
        df["항목명"][idx] = dic_element[re.findall("_\w{1,}", df["항목코드"][idx])[0].lower()][0]

# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df2019["회사명"].unique()
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df[df["회사명"] == i]["결산기준일"].unique())
    day.append(len(df[df["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
add_df = pd.DataFrame(bon, columns = col)


dic_standard = {i:list(df[df["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df[(df["회사명"] == last_company[idx]) & (df["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        add_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = dic_element[re.findall("_\w{1,}", a["항목코드"][idx3])[0].lower()][0]
            add_df.loc[cnt, loc] = a["전전기"][idx3]
    cnt += 1

add_df["결산기준일"] = add_df["결산기준일"].str.replace("2019", "2017")

last_df = pd.concat([last_df, add_df]).reset_index(drop = True)

# %%
last_df.to_csv("./data/2017_2019_without_entity.csv", encoding = "euc-kr", index = False)
