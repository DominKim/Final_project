# %% [markdown]
# ### 1.data load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

#  data load
df2019 = pd.read_csv("./data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

# %%
df2019[df2019["회사명"] == "코스온"]
# Out:
#                       재무제표종류      종목코드  회사명       시장구분   업종          업종명  결산월  \
# 67286  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67287  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67288  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67289  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67290  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67291  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67292  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67293  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67294  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67295  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67296  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67297  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67298  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67299  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67300  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67301  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67302  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67303  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67304  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67305  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67306  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67307  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67308  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67309  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67310  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67311  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67312  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67313  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67314  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67315  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67316  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67317  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67318  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67319  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67320  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67321  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67322  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67323  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67324  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67325  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67326  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67327  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67328  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67329  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67330  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67331  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67332  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67333  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67334  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67335  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67336  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67337  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67338  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67339  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67340  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67341  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67342  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67343  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67344  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
# 67345  재무상태표, 유동/비유동법-연결재무제표  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12
#
#             결산기준일  보고서종류   통화  \
# 67286  2019-12-31  사업보고서  KRW
# 67287  2019-12-31  사업보고서  KRW
# 67288  2019-12-31  사업보고서  KRW
# 67289  2019-12-31  사업보고서  KRW
# 67290  2019-12-31  사업보고서  KRW
# 67291  2019-12-31  사업보고서  KRW
# 67292  2019-12-31  사업보고서  KRW
# 67293  2019-12-31  사업보고서  KRW
# 67294  2019-12-31  사업보고서  KRW
# 67295  2019-12-31  사업보고서  KRW
# 67296  2019-12-31  사업보고서  KRW
# 67297  2019-12-31  사업보고서  KRW
# 67298  2019-12-31  사업보고서  KRW
# 67299  2019-12-31  사업보고서  KRW
# 67300  2019-12-31  사업보고서  KRW
# 67301  2019-12-31  사업보고서  KRW
# 67302  2019-12-31  사업보고서  KRW
# 67303  2019-12-31  사업보고서  KRW
# 67304  2019-12-31  사업보고서  KRW
# 67305  2019-12-31  사업보고서  KRW
# 67306  2019-12-31  사업보고서  KRW
# 67307  2019-12-31  사업보고서  KRW
# 67308  2019-12-31  사업보고서  KRW
# 67309  2019-12-31  사업보고서  KRW
# 67310  2019-12-31  사업보고서  KRW
# 67311  2019-12-31  사업보고서  KRW
# 67312  2019-12-31  사업보고서  KRW
# 67313  2019-12-31  사업보고서  KRW
# 67314  2019-12-31  사업보고서  KRW
# 67315  2019-12-31  사업보고서  KRW
# 67316  2019-12-31  사업보고서  KRW
# 67317  2019-12-31  사업보고서  KRW
# 67318  2019-12-31  사업보고서  KRW
# 67319  2019-12-31  사업보고서  KRW
# 67320  2019-12-31  사업보고서  KRW
# 67321  2019-12-31  사업보고서  KRW
# 67322  2019-12-31  사업보고서  KRW
# 67323  2019-12-31  사업보고서  KRW
# 67324  2019-12-31  사업보고서  KRW
# 67325  2019-12-31  사업보고서  KRW
# 67326  2019-12-31  사업보고서  KRW
# 67327  2019-12-31  사업보고서  KRW
# 67328  2019-12-31  사업보고서  KRW
# 67329  2019-12-31  사업보고서  KRW
# 67330  2019-12-31  사업보고서  KRW
# 67331  2019-12-31  사업보고서  KRW
# 67332  2019-12-31  사업보고서  KRW
# 67333  2019-12-31  사업보고서  KRW
# 67334  2019-12-31  사업보고서  KRW
# 67335  2019-12-31  사업보고서  KRW
# 67336  2019-12-31  사업보고서  KRW
# 67337  2019-12-31  사업보고서  KRW
# 67338  2019-12-31  사업보고서  KRW
# 67339  2019-12-31  사업보고서  KRW
# 67340  2019-12-31  사업보고서  KRW
# 67341  2019-12-31  사업보고서  KRW
# 67342  2019-12-31  사업보고서  KRW
# 67343  2019-12-31  사업보고서  KRW
# 67344  2019-12-31  사업보고서  KRW
# 67345  2019-12-31  사업보고서  KRW
#
#                                                     항목코드  \
# 67286                           ifrs-full_AssetsAbstract
# 67287                            ifrs-full_CurrentAssets
# 67288                   ifrs-full_CashAndCashEquivalents
# 67289          ifrs-full_TradeAndOtherCurrentReceivables
# 67290              ifrs-full_OtherCurrentFinancialAssets
# 67291                              ifrs-full_Inventories
# 67292  entity00402989_udf_BS_201881011137958_CurrentA...
# 67293  entity00402989_udf_BS_201832010538640_CurrentA...
# 67294                         ifrs-full_NoncurrentAssets
# 67295  dart_LongTermTradeAndOtherNonCurrentReceivable...
# 67296  ifrs-full_InvestmentsInSubsidiariesJointVentur...
# 67297                ifrs-full_PropertyPlantAndEquipment
# 67298        ifrs-full_IntangibleAssetsOtherThanGoodwill
# 67299           ifrs-full_OtherNoncurrentFinancialAssets
# 67300                       dart_LongTermPrepaidExpenses
# 67301                        ifrs-full_DeferredTaxAssets
# 67302                                   ifrs-full_Assets
# 67303                      ifrs-full_LiabilitiesAbstract
# 67304                       ifrs-full_CurrentLiabilities
# 67305             ifrs-full_TradeAndOtherCurrentPayables
# 67306  entity00402989_udf_BS_2018810112128284_Current...
# 67307                    ifrs-full_CurrentTaxLiabilities
# 67308                      ifrs-full_ShorttermBorrowings
# 67309                        ifrs-full_CurrentProvisions
# 67310              dart_CurrentPortionOfConvertibleBonds
# 67311               dart_CurrentPortionOfBondWithWarrant
# 67312        dart_CurentPortionOfFinanceLeaseLiabilities
# 67313                  dart_CurrentDerivativeLiabilities
# 67314                    ifrs-full_NoncurrentLiabilities
# 67315                       dart_LongTermBorrowingsGross
# 67316                               dart_BondWithWarrant
# 67317                              dart_ConvertibleBonds
# 67318             dart_NonCurrentFinanceLeaseLiabilities
# 67319             dart_LongTermGuaranteeDepositRentGross
# 67320          dart_NonCurrentProvisionsForReturnedGoods
# 67321                   ifrs-full_DeferredTaxLiabilities
# 67322                              ifrs-full_Liabilities
# 67323                           ifrs-full_EquityAbstract
# 67324       ifrs-full_EquityAttributableToOwnersOfParent
# 67325  entity00402989_udf_BS_2017111363847677_EquityA...
# 67326                            ifrs-full_IssuedCapital
# 67327                    dart_IssuedCapitalOfCommonStock
# 67328                 dart_IssuedCapitalOfPreferredStock
# 67329                             ifrs-full_SharePremium
# 67330             dart_ElementsOfOtherStockholdersEquity
# 67331  entity00402989_udf_BS_2017111364040804_Element...
# 67332  entity00402989_udf_BS_20193710459419_ElementsO...
# 67333                                  dart_StockOptions
# 67334  entity00402989_udf_BS_2020311114221829_Element...
# 67335                           ifrs-full_TreasuryShares
# 67336                       dart_LossesSaleTreasuryStock
# 67337  entity00402989_udf_BS_201711136413125_Elements...
# 67338  entity00402989_udf_BS_202031111416276_Elements...
# 67339  entity00402989_udf_BS_2017111364129385_Element...
# 67340                       dart_OtherCapitalAdjustments
# 67341                         ifrs-full_RetainedEarnings
# 67342  dart_RetainedEarningsBeforeAppropriationsAccum...
# 67343                  ifrs-full_NoncontrollingInterests
# 67344  entity00402989_udf_BS_201881313142769_EquityAb...
# 67345  entity00402989_udf_BS_2018813131724397_Stateme...
#
#                              항목명               당기               전기  \
# 67286              자산 [abstract]              NaN              NaN
# 67287                       유동자산   95,604,972,531  129,903,381,616
# 67288                   현금및현금성자산   12,539,024,962   29,094,729,446
# 67289              매출채권 및 기타유동채권   53,337,973,844   64,305,198,234
# 67290                   기타유동금융자산    3,904,318,700    2,600,000,000
# 67291                       재고자산   25,589,650,740   32,086,358,812
# 67292                       환불자산      234,004,285      146,020,355
# 67293                  매각예정비유동자산              NaN    1,671,074,769
# 67294                      비유동자산  144,356,894,454   91,543,912,414
# 67295              당기손익-공정가치금융자산   14,860,067,457   10,788,491,894
# 67296            관계기업 및 종속기업투자자산    2,345,404,793    3,674,696,020
# 67297                       유형자산  110,461,938,765   65,887,347,687
# 67298                       무형자산    4,776,834,413    4,782,808,785
# 67299                  기타비유동금융자산    8,113,457,718    3,983,062,383
# 67300                     장기선급비용    1,921,328,970    1,948,485,572
# 67301                    이연법인세자산    1,877,862,338      479,020,073
# 67302                       자산총계  239,961,866,985  221,447,294,030
# 67303              부채 [abstract]              NaN              NaN
# 67304                       유동부채  100,061,257,937   96,060,235,339
# 67305              매입채무 및 기타유동채무   20,189,698,914   19,364,298,612
# 67306                       환불부채      271,593,302      167,730,143
# 67307                    당기법인세부채      898,140,555    1,077,824,829
# 67308                      단기차입금   22,934,777,390   38,194,180,548
# 67309                    유동성장기부채    1,358,572,999    4,649,996,000
# 67310                    유동성전환사채   40,997,192,512   32,606,205,207
# 67311                유동성신주인수권부사채    3,873,115,369              NaN
# 67312                  유동성금융리스부채      689,456,006              NaN
# 67313                   유동파생상품부채    8,848,710,890              NaN
# 67314                      비유동부채   31,968,234,518   12,985,768,232
# 67315                      장기차입금   14,373,425,001    8,768,998,000
# 67316                   신주인수권부사채              NaN    3,560,770,232
# 67317                       전환사채              NaN              NaN
# 67318                     금융리스부채   16,938,809,517              NaN
# 67319                      임대보증금      656,000,000      656,000,000
# 67320                  비유동반품충당부채              NaN              NaN
# 67321                    이연법인세부채              NaN              NaN
# 67322                       부채총계  132,029,492,455  109,046,003,571
# 67323              자본 [abstract]              NaN              NaN
# 67324        지배기업의 소유주에게 귀속되는 자본              NaN              NaN
# 67325                       납입자본   96,148,751,742   96,148,751,742
# 67326                        자본금   11,104,396,500   11,104,396,500
# 67327                     보통주자본금    9,348,580,500    9,348,580,500
# 67328                     우선주자본금    1,755,816,000    1,755,816,000
# 67329                    주식발행초과금   85,044,355,242   85,044,355,242
# 67330                   기타자본구성요소    7,299,777,757    5,069,143,771
# 67331                      전환권대가    4,668,166,172    4,956,520,168
# 67332                    신주인수권대가      439,229,768      439,229,768
# 67333                    주식매수선택권      890,187,500      680,400,000
# 67334                    지분법자본변동      287,871,765              NaN
# 67335                       자기주식    1,066,235,950    1,066,235,950
# 67336                   자기주식처분이익     -418,931,386     -418,931,386
# 67337                  신주인수권처분이익       20,000,000       20,000,000
# 67338                 지배주주와의자본거래     -130,669,605              NaN
# 67339                해외사업장환산외환차이     -232,080,439     -379,701,601
# 67340                     기타자본조정    2,004,377,160              NaN
# 67341                 이익잉여금(결손금)    2,375,868,288    7,687,880,621
# 67342           미처분이익잉여금(미처리결손금)    2,375,868,288    7,687,880,621
# 67343                      비지배지분    2,107,976,743    3,495,514,325
# 67344                     자본의 총계  107,932,374,530  112,401,290,459
# 67345                 자본과 부채의 총계  239,961,866,985  221,447,294,030
#
#                    전전기  Unnamed: 15
# 67286              NaN          NaN
# 67287   87,335,695,062          NaN
# 67288    5,907,165,250          NaN
# 67289   43,380,327,241          NaN
# 67290              NaN          NaN
# 67291   34,134,524,113          NaN
# 67292              NaN          NaN
# 67293    3,913,678,458          NaN
# 67294   52,097,295,748          NaN
# 67295              NaN          NaN
# 67296    2,972,993,486          NaN
# 67297   31,517,237,836          NaN
# 67298      568,634,751          NaN
# 67299   17,038,429,675          NaN
# 67300              NaN          NaN
# 67301              NaN          NaN
# 67302  139,432,990,810          NaN
# 67303              NaN          NaN
# 67304   35,752,074,465          NaN
# 67305   17,027,117,246          NaN
# 67306              NaN          NaN
# 67307       76,858,406          NaN
# 67308   15,631,920,656          NaN
# 67309    2,899,996,000          NaN
# 67310              NaN          NaN
# 67311              NaN          NaN
# 67312      116,182,157          NaN
# 67313              NaN          NaN
# 67314   31,567,778,001          NaN
# 67315    4,899,994,000          NaN
# 67316              NaN          NaN
# 67317   25,756,100,822          NaN
# 67318      100,000,000          NaN
# 67319      703,000,000          NaN
# 67320       52,758,909          NaN
# 67321       55,924,270          NaN
# 67322   67,319,852,466          NaN
# 67323              NaN          NaN
# 67324              NaN          NaN
# 67325   54,802,415,012          NaN
# 67326    9,404,883,500          NaN
# 67327    9,060,357,000          NaN
# 67328      344,526,500          NaN
# 67329   45,397,531,512          NaN
# 67330    5,257,295,792          NaN
# 67331    5,070,906,464          NaN
# 67332              NaN          NaN
# 67333      982,800,000          NaN
# 67334              NaN          NaN
# 67335    1,066,235,950          NaN
# 67336     -418,931,386          NaN
# 67337       20,000,000          NaN
# 67338              NaN          NaN
# 67339     -169,106,108          NaN
# 67340              NaN          NaN
# 67341   10,662,386,639          NaN
# 67342   10,662,386,639          NaN
# 67343    1,391,040,901          NaN
# 67344   72,113,138,344          NaN
# 67345  139,432,990,810          NaN

# %% [markdown]
# ### 2. 불필요한 변수 제거

# %%
# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("전기", axis = 1, inplace = True)
    data.drop("전전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df2019 = delete_col(df2019)

# %% [markdown]
# ### 3. 연속형변수(당기, 전기, 전전기)  dtype 변경

# %%
def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
#     data["전기"] = data["전기"].str.replace(",", "")
#     data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    return data

df2019 = str_to_float(df2019)

# %% [markdown]
# ### 4. 항목명 변수 처리

# %%
def duplication_check(data):
    # 항목코드 중복 확인
    entity_코드 = []
    entity_명 = []
    without_entity_코드 = []
    without_entity_명 = []

    # 각 리스트에 코드 및 코드명 append(소문자 처리)
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            entity_코드.append(data["항목코드"][idx].lower())
            entity_명.append(data["항목명"][idx].lower())
        else:
            without_entity_코드.append(data["항목코드"][idx].lower())
            without_entity_명.append(data["항목명"][idx].lower())

    # !entity 코드 딕셔너리
    dic_without_entity = {re.findall("_\w{1,}", without_entity_코드[idx])[0].lower():[] for idx in range(len(without_entity_코드))}

    for i, j in zip(without_entity_코드, without_entity_명):
        dic_without_entity[re.findall("_\w{1,}", i)[0].lower()].append(j)

    check_without_entity = {i:len(set(j)) for i, j in dic_without_entity.items()}
    
    # entity 코드 딕셔너리
    dic_entity = {entity_코드[idx]:[] for idx in range(len(entity_코드))}
    
    for i, j in zip(entity_코드, entity_명):
        dic_entity[i].append(j)
        
    check_entity = {i:len(set(j)) for i, j in dic_entity.items()}
    
    return entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity

entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity = duplication_check(df2019)

# %% [markdown]
# ### 5. 공시된 항목명, 항목코드 가져오기(금융감독원 재무제표 양식)

# %%
def extract_element_id(data):
    element_idx_lst_entity = []
    element_idx_lst_without_entity = []
    
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            element_idx_lst_entity.append(data["항목코드"][idx])
        else:
            element_idx_lst_without_entity.append(data["항목코드"][idx])
            
    entity = sorted(set(element_idx_lst_entity), reverse = True)
    without_entity = sorted(set(element_idx_lst_without_entity), reverse = True)
    
    return entity, without_entity

a, b = extract_element_id(df2019)
pd.Series(b).to_csv("./2019항목명.csv", encoding = "euc-kr", index = False)

elementid = pd.read_excel("./data/재무제표양식.xlsx", encoding = "utf-8", sheet_name = "BS1")
# '한글 Label', 'Element ID'
df_element = elementid[['한글 Label', 'Element ID']]
df_element = df_element[df_element["Element ID"].notnull()]

df_element.columns = df_element.columns.str.replace(" ", "_")
lst_element = df_element["Element_ID"].unique()

re_lst_element = []
for i in lst_element:
    a = re.findall("_\w{1,}", i)[0].lower()
    re_lst_element.append(a)
 
dic_element = {i:[] for i in re_lst_element}
for i, j in zip(re_lst_element, df_element["한글_Label"]):
    dic_element[i].append(j)

# %% [markdown]
# ### 6. entity 제외 항목명 변수 전처리

# %%
for idx in range(len(df2019)):
    if "entity" not in df2019["항목코드"][idx]:
        df2019["항목명"][idx] = dic_element[re.findall("_\w{1,}", df2019["항목코드"][idx])[0].lower()][0]
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2019[df2019["회사명"] == "코스온"]
# Out:
#            종목코드  회사명       시장구분   업종          업종명  결산월       결산기준일  보고서종류  \
# 67286  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67287  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67288  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67289  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67290  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67291  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67292  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67293  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67294  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67295  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67296  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67297  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67298  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67299  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67300  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67301  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67302  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67303  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67304  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67305  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67306  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67307  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67308  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67309  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67310  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67311  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67312  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67313  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67314  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67315  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67316  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67317  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67318  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67319  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67320  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67321  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67322  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67323  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67324  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67325  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67326  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67327  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67328  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67329  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67330  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67331  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67332  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67333  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67334  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67335  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67336  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67337  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67338  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67339  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67340  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67341  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67342  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67343  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67344  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
# 67345  [069110]  코스온  코스닥시장상장법인  204  기타 화학제품 제조업   12  2019-12-31  사업보고서
#
#                                                     항목코드  \
# 67286                           ifrs-full_AssetsAbstract
# 67287                            ifrs-full_CurrentAssets
# 67288                   ifrs-full_CashAndCashEquivalents
# 67289          ifrs-full_TradeAndOtherCurrentReceivables
# 67290              ifrs-full_OtherCurrentFinancialAssets
# 67291                              ifrs-full_Inventories
# 67292  entity00402989_udf_BS_201881011137958_CurrentA...
# 67293  entity00402989_udf_BS_201832010538640_CurrentA...
# 67294                         ifrs-full_NoncurrentAssets
# 67295  dart_LongTermTradeAndOtherNonCurrentReceivable...
# 67296  ifrs-full_InvestmentsInSubsidiariesJointVentur...
# 67297                ifrs-full_PropertyPlantAndEquipment
# 67298        ifrs-full_IntangibleAssetsOtherThanGoodwill
# 67299           ifrs-full_OtherNoncurrentFinancialAssets
# 67300                       dart_LongTermPrepaidExpenses
# 67301                        ifrs-full_DeferredTaxAssets
# 67302                                   ifrs-full_Assets
# 67303                      ifrs-full_LiabilitiesAbstract
# 67304                       ifrs-full_CurrentLiabilities
# 67305             ifrs-full_TradeAndOtherCurrentPayables
# 67306  entity00402989_udf_BS_2018810112128284_Current...
# 67307                    ifrs-full_CurrentTaxLiabilities
# 67308                      ifrs-full_ShorttermBorrowings
# 67309                        ifrs-full_CurrentProvisions
# 67310              dart_CurrentPortionOfConvertibleBonds
# 67311               dart_CurrentPortionOfBondWithWarrant
# 67312        dart_CurentPortionOfFinanceLeaseLiabilities
# 67313                  dart_CurrentDerivativeLiabilities
# 67314                    ifrs-full_NoncurrentLiabilities
# 67315                       dart_LongTermBorrowingsGross
# 67316                               dart_BondWithWarrant
# 67317                              dart_ConvertibleBonds
# 67318             dart_NonCurrentFinanceLeaseLiabilities
# 67319             dart_LongTermGuaranteeDepositRentGross
# 67320          dart_NonCurrentProvisionsForReturnedGoods
# 67321                   ifrs-full_DeferredTaxLiabilities
# 67322                              ifrs-full_Liabilities
# 67323                           ifrs-full_EquityAbstract
# 67324       ifrs-full_EquityAttributableToOwnersOfParent
# 67325  entity00402989_udf_BS_2017111363847677_EquityA...
# 67326                            ifrs-full_IssuedCapital
# 67327                    dart_IssuedCapitalOfCommonStock
# 67328                 dart_IssuedCapitalOfPreferredStock
# 67329                             ifrs-full_SharePremium
# 67330             dart_ElementsOfOtherStockholdersEquity
# 67331  entity00402989_udf_BS_2017111364040804_Element...
# 67332  entity00402989_udf_BS_20193710459419_ElementsO...
# 67333                                  dart_StockOptions
# 67334  entity00402989_udf_BS_2020311114221829_Element...
# 67335                           ifrs-full_TreasuryShares
# 67336                       dart_LossesSaleTreasuryStock
# 67337  entity00402989_udf_BS_201711136413125_Elements...
# 67338  entity00402989_udf_BS_202031111416276_Elements...
# 67339  entity00402989_udf_BS_2017111364129385_Element...
# 67340                       dart_OtherCapitalAdjustments
# 67341                         ifrs-full_RetainedEarnings
# 67342  dart_RetainedEarningsBeforeAppropriationsAccum...
# 67343                  ifrs-full_NoncontrollingInterests
# 67344  entity00402989_udf_BS_201881313142769_EquityAb...
# 67345  entity00402989_udf_BS_2018813131724397_Stateme...
#
#                               항목명            당기
# 67286               자산 [abstract]           NaN
# 67287                        유동자산  9.560497e+10
# 67288                    현금및현금성자산  1.253903e+10
# 67289               매출채권 및 기타유동채권  5.333797e+10
# 67290                    기타유동금융자산  3.904319e+09
# 67291                        재고자산  2.558965e+10
# 67292                        환불자산  2.340043e+08
# 67293                   매각예정비유동자산           NaN
# 67294                       비유동자산  1.443569e+11
# 67295            장기매출채권 및 기타비유동채권  1.486007e+10
# 67296  종속기업, 조인트벤처와 관계기업에 대한 투자자산  2.345405e+09
# 67297                        유형자산  1.104619e+11
# 67298                영업권 이외의 무형자산  4.776835e+09
# 67299                   기타비유동금융자산  8.113458e+09
# 67300                      장기선급비용  1.921329e+09
# 67301                     이연법인세자산  1.877862e+09
# 67302                        자산총계  2.399619e+11
# 67303               부채 [abstract]           NaN
# 67304                        유동부채  1.000613e+11
# 67305               매입채무 및 기타유동채무  2.018970e+10
# 67306                        환불부채  2.715933e+08
# 67307                     당기법인세부채  8.981405e+08
# 67308                       단기차입금  2.293478e+10
# 67309                      유동충당부채  1.358573e+09
# 67310                     유동성전환사채  4.099719e+10
# 67311                 유동성신주인수권부사채  3.873115e+09
# 67312                   유동성금융리스부채  6.894560e+08
# 67313                    유동파생상품부채  8.848711e+09
# 67314                       비유동부채  3.196824e+10
# 67315                       장기차입금  1.437343e+10
# 67316                    신주인수권부사채           NaN
# 67317                        전환사채           NaN
# 67318                   비유동금융리스부채  1.693881e+10
# 67319                     장기임대보증금  6.560000e+08
# 67320                   비유동반품충당부채           NaN
# 67321                     이연법인세부채           NaN
# 67322                        부채총계  1.320295e+11
# 67323               자본 [abstract]           NaN
# 67324         지배기업의 소유주에게 귀속되는 자본           NaN
# 67325                        납입자본  9.614875e+10
# 67326                         자본금  1.110440e+10
# 67327                      보통주자본금  9.348580e+09
# 67328                      우선주자본금  1.755816e+09
# 67329                     주식발행초과금  8.504436e+10
# 67330                    기타자본구성요소  7.299778e+09
# 67331                       전환권대가  4.668166e+09
# 67332                     신주인수권대가  4.392298e+08
# 67333                       주식선택권  8.901875e+08
# 67334                     지분법자본변동  2.878718e+08
# 67335                        자기주식  1.066236e+09
# 67336                    자기주식처분손실 -4.189314e+08
# 67337                   신주인수권처분이익  2.000000e+07
# 67338                  지배주주와의자본거래 -1.306696e+08
# 67339                 해외사업장환산외환차이 -2.320804e+08
# 67340                      기타자본조정  2.004377e+09
# 67341                  이익잉여금(결손금)  2.375868e+09
# 67342            미처분이익잉여금(미처리결손금)  2.375868e+09
# 67343                       비지배지분  2.107977e+09
# 67344                      자본의 총계  1.079324e+11
# 67345                  자본과 부채의 총계  2.399619e+11

# %% [markdown]
# ### 7. 정제된 데이터 프레임 만들기

# %%
# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df2019["회사명"].unique()
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df2019.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df2019[df2019["회사명"] == i]["결산기준일"].unique())
    day.append(len(df2019[df2019["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
last_df = pd.DataFrame(bon, columns = col)

# %% [markdown]
# ### 8. 데이터 입력

# %%
dic_standard = {i:list(df2019[df2019["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df2019[(df2019["회사명"] == last_company[idx]) & (df2019["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        last_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = dic_element[re.findall("_\w{1,}", a["항목코드"][idx3])[0].lower()][0]
            last_df.loc[cnt, loc] = a["당기"][idx3]
    cnt += 1

# %% [markdown]
# ### 9. 2018데이터 입력

# %%
# 2018년 변수 처리
df = pd.read_csv("./data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
    data["전기"] = data["전기"].str.replace(",", "")
    data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    data["전기"] = data["전기"].astype(np.float32)
    data["전전기"] = data["전전기"].astype(np.float32)
    return data

df = str_to_float(df)

# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("당기", axis = 1, inplace = True)
    data.drop("전전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df = delete_col(df)

# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df2019["회사명"].unique()
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df[df["회사명"] == i]["결산기준일"].unique())
    day.append(len(df[df["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
add_df = pd.DataFrame(bon, columns = col)


dic_standard = {i:list(df[df["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df[(df["회사명"] == last_company[idx]) & (df["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        add_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = dic_element[re.findall("_\w{1,}", a["항목코드"][idx3])[0].lower()][0]
            add_df.loc[cnt, loc] = a["전기"][idx3]
    cnt += 1

add_df["결산기준일"] = add_df["결산기준일"].str.replace("2019", "2018")

last_df = pd.concat([last_df, add_df]).reset_index(drop = True)

# %% [markdown]
# ### 10. 2017 데이터 입력

# %%
# 2017년 변수 처리
df = pd.read_csv("./data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
    data["전기"] = data["전기"].str.replace(",", "")
    data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    data["전기"] = data["전기"].astype(np.float32)
    data["전전기"] = data["전전기"].astype(np.float32)
    return data

df = str_to_float(df)

# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("당기", axis = 1, inplace = True)
    data.drop("전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df = delete_col(df)

# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df2019["회사명"].unique()
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df[df["회사명"] == i]["결산기준일"].unique())
    day.append(len(df[df["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
add_df = pd.DataFrame(bon, columns = col)


dic_standard = {i:list(df[df["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df[(df["회사명"] == last_company[idx]) & (df["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        add_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = dic_element[re.findall("_\w{1,}", a["항목코드"][idx3])[0].lower()][0]
            add_df.loc[cnt, loc] = a["전전기"][idx3]
    cnt += 1

add_df["결산기준일"] = add_df["결산기준일"].str.replace("2019", "2017")

last_df = pd.concat([last_df, add_df]).reset_index(drop = True)

# %%
last_df.to_csv("./data/2017_2019_without_entity.csv", encoding = "euc-kr", index = False)

# %%
df2019[(df2019["회사명"] == "리드코프") & (df2019["항목명"] == '      차입부채')]
# Out:
#            종목코드   회사명       시장구분   업종        업종명  결산월       결산기준일  보고서종류  \
# 23746  [012700]  리드코프  코스닥시장상장법인  467  기타 전문 도매업   12  2019-12-31  사업보고서
#
#                                                     항목코드         항목명  \
# 23746  entity00117708_udf_BS_202031793352138_udf_BS_2...        차입부채
#
#                  전기
# 23746  7.363806e+11

# %%
last_df[last_df["회사명"] == "3S"]
# Out:
#           종목코드 회사명       시장구분     업종            업종명  결산월       결산기준일  보고서종류  \
# 0     [060310]  3S  코스닥시장상장법인  292.0  특수 목적용 기계 제조업  3.0  2019-03-31  사업보고서
# 1692  [060310]  3S  코스닥시장상장법인  292.0  특수 목적용 기계 제조업  3.0  2018-03-31  사업보고서
# 3384  [060310]  3S  코스닥시장상장법인  292.0  특수 목적용 기계 제조업  3.0  2017-03-31  사업보고서
#
#       재무상태표 [abstract]  자산 [abstract]  ...  현금흐름위험회피파생상품평가손실  지분법기타포괄손익변동  \
# 0                  NaN            NaN  ...               NaN          NaN
# 1692               NaN            NaN  ...               NaN          NaN
# 3384               NaN            NaN  ...               NaN          NaN
#
#         이익잉여금(결손금)  이익준비금  기타법정적립금  임의적립금  미처분이익잉여금(미처리결손금)  비지배지분  \
# 0    -3.167278e+10    NaN      NaN    NaN               NaN    0.0
# 1692 -3.236181e+10    NaN      NaN    NaN               NaN    0.0
# 3384 -3.092958e+10    NaN      NaN    NaN               NaN    0.0
#
#               자본총계       자본과부채총계
# 0     3.437168e+10  5.332922e+10
# 1692  3.075234e+10  4.952100e+10
# 3384  2.917967e+10  5.370690e+10
#
# [3 rows x 527 columns]

# %%
df.to_csv("./data/2019_2017변수확인.csv", index = False, encoding = "euc-kr")
