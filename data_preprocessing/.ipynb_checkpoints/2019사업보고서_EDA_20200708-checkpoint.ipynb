# %% [markdown]
# ### 1.data load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

#  data load
df2019 = pd.read_csv("../data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

# %% [markdown]
# ### 2. 불필요한 변수 제거

# %%
# 필요 없는 변수 제거
def delete_col(data):
#     data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("전기", axis = 1, inplace = True)
    data.drop("전전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df2019 = delete_col(df2019)

# %% [markdown]
# ### 3. 연속형변수(당기, 전기, 전전기)  dtype 변경

# %%
def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
#     data["전기"] = data["전기"].str.replace(",", "")
#     data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    return data

df2019 = str_to_float(df2019)

# %% [markdown]
# ### 4. 항목명 변수 처리

# %%
def duplication_check(data):
    # 항목코드 중복 확인
    entity_코드 = []
    entity_명 = []
    without_entity_코드 = []
    without_entity_명 = []

    # 각 리스트에 코드 및 코드명 append(소문자 처리)
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            entity_코드.append(data["항목코드"][idx].lower())
            entity_명.append(data["항목명"][idx].lower())
        else:
            without_entity_코드.append(data["항목코드"][idx].lower())
            without_entity_명.append(data["항목명"][idx].lower())

    # !entity 코드 딕셔너리
    dic_without_entity = {re.findall("_\w{1,}", without_entity_코드[idx])[0].lower():[] for idx in range(len(without_entity_코드))}

    for i, j in zip(without_entity_코드, without_entity_명):
        dic_without_entity[re.findall("_\w{1,}", i)[0].lower()].append(j)

    check_without_entity = {i:len(set(j)) for i, j in dic_without_entity.items()}
    
    # entity 코드 딕셔너리
    dic_entity = {entity_코드[idx]:[] for idx in range(len(entity_코드))}
    
    for i, j in zip(entity_코드, entity_명):
        dic_entity[i].append(j)
        
    check_entity = {i:len(set(j)) for i, j in dic_entity.items()}
    
    return entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity

entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity = duplication_check(df2019)

# %% [markdown]
# ### 5. 공시된 항목명, 항목코드 가져오기(금융감독원 재무제표 양식)

# %%
def extract_element_id(data):
    element_idx_lst_entity = []
    element_idx_lst_without_entity = []
    
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            element_idx_lst_entity.append(data["항목코드"][idx])
        else:
            element_idx_lst_without_entity.append(data["항목코드"][idx])
            
    entity = sorted(set(element_idx_lst_entity), reverse = True)
    without_entity = sorted(set(element_idx_lst_without_entity), reverse = True)
    
    return entity, without_entity

a, b = extract_element_id(df2019)
pd.Series(b).to_csv("../2019항목명.csv", encoding = "euc-kr", index = False)

elementid = pd.read_excel("../data/재무제표양식.xlsx", encoding = "utf-8", sheet_name = "BS1")
# '한글 Label', 'Element ID'
df_element = elementid[['한글 Label', 'Element ID']]
df_element = df_element[df_element["Element ID"].notnull()]

df_element.columns = df_element.columns.str.replace(" ", "_")
lst_element = df_element["Element_ID"].unique()

re_lst_element = []
for i in lst_element:
    a = re.findall("_\w{1,}", i)[0].lower()
    re_lst_element.append(a)
 
dic_element = {i:[] for i in re_lst_element}
for i, j in zip(re_lst_element, df_element["한글_Label"]):
    dic_element[i].append(j)

# %% [markdown]
# ### 5-1. 항목명 entity 값 처리(ver_1)

# %%
# 항목명 전치리

# 1) _가진 항목명 추출
lst_ = []
for i in range(len(df2019)):
    if "_" in df2019.loc[i, "항목명"]:
        lst_.append(i)
        
def preprocessing(x):
    a = x.replace(" ", "")
    a = a.replace("_", "")
    a = a.replace("[", "")
    a = a.replace("]", "")
    a = a.replace("(", "")
    a = a.replace(")", "")
    a = a.replace(".", "")
    a = re.sub("[ⅠⅡⅢⅣⅤIII]", "", a)
    a = re.sub("[1-9]", "", a)
    
    
    return a

df2019["항목명"] = df2019["항목명"].agg(preprocessing)

lst_idx = []
for i in range(len(df2019)):
    if "총계" in df2019["항목명"][i] and "entity" in df2019["항목코드"][i]:
        lst_idx.append(i)
        
for i in lst_idx:
    if df2019["항목명"][i] == '부채총계':
        df2019["항목코드"][i] = "ifrs-full_Liabilities"
        
    elif df2019["항목명"][i] == '자본과부채의총계':
        df2019["항목코드"][i] = "ifrs-full_EquityAndLiabilities"
        
    elif df2019["항목명"][i] == '자산총계':
        df2019["항목코드"][i] = "ifrs-full_Assets"
        
    else:
        df2019["항목코드"][i] = "ifrs-full_Equity"

# %%
df2019[df2019["항목명"] == "계약부채"]["항목코드"].value_counts()

# %% [markdown]
# ### 6. entity 제외 항목명 변수 전처리

# %%
for idx in range(len(df2019)):
    if "entity" not in df2019["항목코드"][idx]:
        df2019["항목명"][idx] = dic_element[re.findall("_\w{1,}", df2019["항목코드"][idx])[0].lower()][0]
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### 6-1. entity 변수 전처리

# %%
elementid = pd.read_excel("../data/재무제표양식.xlsx", encoding = "utf-8", sheet_name = "BS1")
# '한글 Label', 'Element ID'
df_element = elementid[['한글 Label', 'Element ID']]
df_element = df_element[df_element["Element ID"].notnull()]

df_element.columns = df_element.columns.str.replace(" ", "_")
lst_element = df_element["Element_ID"].unique()

re_lst_element = []
for i in lst_element:
    a = re.findall("_\w{1,}", i)[0].lower()
    re_lst_element.append(a)
 
dic_elementid = {(((i.replace("_", "")).replace(" ", "")).replace("[", "")).replace("]", ""):j 
                 for i, j in zip(df_element["한글_Label"], df_element["Element_ID"])}


# entity 포함 항목코드 항목코드 전처리
no_preprocessing_entity_idx = []
for idx in idx_entity:
    try:
        df2019.loc[idx, "항목코드"] = dic_elementid[df2019.loc[idx, "항목명"]]

    except Exception as e:
        no_preprocessing_entity_idx.append(idx)
        
# 한번더 전처리
for idx in range(len(df2019)):
    if "entity" not in df2019["항목코드"][idx]:
        df2019["항목명"][idx] = dic_element[re.findall("_\w{1,}", df2019["항목코드"][idx])[0].lower()][0]
        

# 항목명이 같은 entity 변수 전처리
lst = []
for idx in range(len(df2019)):
    if "entity" in df2019.loc[idx, "항목코드"]:
        lst.append(idx)
        
no_preprocessing = []
for idx in lst:
    try:
        df2019.loc[idx, "항목코드"] = dic_elementid[df2019.loc[idx, "항목명"]]
    except Exception as e:
        no_preprocessing.append(idx)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### 6-2. 새로운 기준 입히기

# %%
# 새 기준 양식 불러오기
new_criterion = pd.read_excel("../data/개선코드표.xlsx", encoding = "utf-8", sheet_name = "2")
new_criterion

dic_re_code = {re.findall("_\w{1,}",i)[0]:j for i,j in zip(new_criterion["항목코드"], new_criterion["개선항목코드"])}
dic_re_name = {re.findall("_\w{1,}",i)[0]:j for i,j in zip(new_criterion["항목코드"], new_criterion["개선항목명"])}

# 새기준 양식으로 항목명 
for idx in range(len(df2019)):
    if "entity" not in df2019.loc[idx, "항목코드"]:
        df2019.loc[idx, "항목명"] = dic_re_name[re.findall("_\w{1,}", df2019.loc[idx, "항목코드"])[0]]
        df2019.loc[idx, "항목코드"] = dic_re_code[re.findall("_\w{1,}", df2019.loc[idx, "항목코드"])[0]]
        
# 필요 없는 변수 제거
index = df2019[df2019["항목명"] == "지우기"].index
df2019.drop(index, inplace = True)
df2019.reset_index(drop = True, inplace = True)

# %%
df2019[df2019["회사명"] == "한익스프레스"]
# Out:
#            종목코드     회사명        시장구분   업종        업종명  결산월       결산기준일  보고서종류  \
# 78759  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78760  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78761  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78762  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78763  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78764  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78765  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78766  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78767  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78768  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78769  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78770  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78771  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78772  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78773  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78774  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78775  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78776  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78777  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78778  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78779  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78780  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78781  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78782  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78783  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78784  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78785  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78786  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78787  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78788  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78789  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78790  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78791  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78792  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78793  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78794  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78795  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78796  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78797  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78798  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78799  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
# 78800  [014130]  한익스프레스  유가증권시장상장법인  493  도로 화물 운송업   12  2019-12-31  사업보고서
#
#         통화                                               항목코드  \
# 78759  KRW                           ifrs-full_AssetsAbstract
# 78760  KRW                            ifrs-full_CurrentAssets
# 78761  KRW                   ifrs-full_CashAndCashEquivalents
# 78762  KRW          ifrs-full_TradeAndOtherCurrentReceivables
# 78763  KRW                            dart_OtherCurrentAssets
# 78764  KRW                              ifrs-full_Inventories
# 78765  KRW                         ifrs-full_NoncurrentAssets
# 78766  KRW                ifrs-full_PropertyPlantAndEquipment
# 78767  KRW        ifrs-full_IntangibleAssetsOtherThanGoodwill
# 78768  KRW                       ifrs-full_InvestmentProperty
# 78769  KRW           ifrs-full_OtherNoncurrentFinancialAssets
# 78770  KRW  dart_LongTermTradeAndOtherNonCurrentReceivable...
# 78771  KRW  entity00129509_udf_BS_201889144754597_Noncurre...
# 78772  KRW                  ifrs-full_InvestmentsInAssociates
# 78773  KRW                         dart_OtherNonCurrentAssets
# 78774  KRW                        ifrs-full_DeferredTaxAssets
# 78775  KRW                                   ifrs-full_Assets
# 78776  KRW                      ifrs-full_LiabilitiesAbstract
# 78777  KRW                       ifrs-full_CurrentLiabilities
# 78778  KRW             ifrs-full_TradeAndOtherCurrentPayables
# 78779  KRW                      ifrs-full_ShorttermBorrowings
# 78780  KRW                  dart_PaymentsOfIncomeTaxesPayable
# 78781  KRW                       dart_OtherCurrentLiabilities
# 78782  KRW       ifrs-full_CurrentPortionOfLongtermBorrowings
# 78783  KRW  entity00129509_udf_BS_2020311171055290_Current...
# 78784  KRW                    ifrs-full_NoncurrentLiabilities
# 78785  KRW       dart_LongTermTradeAndOtherNonCurrentPayables
# 78786  KRW                       dart_LongTermBorrowingsGross
# 78787  KRW              dart_PostemploymentBenefitObligations
# 78788  KRW                    dart_OtherNonCurrentLiabilities
# 78789  KRW                              ifrs-full_Liabilities
# 78790  KRW                           ifrs-full_EquityAbstract
# 78791  KRW       ifrs-full_EquityAttributableToOwnersOfParent
# 78792  KRW                            ifrs-full_IssuedCapital
# 78793  KRW                    dart_IssuedCapitalOfCommonStock
# 78794  KRW  entity00129509_udf_BS_201711110353784_IssuedCa...
# 78795  KRW  entity00129509_udf_BS_2017111124145817_EquityA...
# 78796  KRW  entity00129509_udf_BS_2017111124421274_udf_BS_...
# 78797  KRW                         ifrs-full_RetainedEarnings
# 78798  KRW                  ifrs-full_NoncontrollingInterests
# 78799  KRW                                   ifrs-full_Equity
# 78800  KRW                     ifrs-full_EquityAndLiabilities
#
#                    항목명            당기
# 78759       자산abstract           NaN
# 78760             유동자산  9.582382e+10
# 78761         현금및현금성자산  4.534174e+09
# 78762      매출채권및기타유동채권  8.554419e+10
# 78763           기타유동자산  3.575754e+09
# 78764             재고자산  2.169707e+09
# 78765            비유동자산  1.706446e+11
# 78766             유형자산  1.472982e+11
# 78767             무형자산  3.055733e+09
# 78768            투자부동산  5.318863e+09
# 78769        기타비유동금융자산  4.000000e+06
# 78770   장기매출채권및기타비유동채권  8.271869e+09
# 78771  당기손익-공정가치측정금융자산  2.473462e+09
# 78772      관계기업에대한투자자산  2.121495e+09
# 78773          기타비유동자산  4.937128e+08
# 78774          이연법인세자산  1.607284e+09
# 78775             자산총계  2.664684e+11
# 78776       부채abstract           NaN
# 78777             유동부채  1.168094e+11
# 78778      매입채무및기타유동채무  6.025943e+10
# 78779            단기차입금  4.003512e+10
# 78780           미지급법인세  9.142550e+08
# 78781           기타유동부채  7.407450e+08
# 78782         유동성장기차입금  4.100000e+09
# 78783           기타금융부채  1.075982e+10
# 78784            비유동부채  7.754705e+10
# 78785   장기매입채무및기타비유동채무  3.860500e+08
# 78786            장기차입금  6.010000e+10
# 78787           퇴직급여부채  3.345545e+08
# 78788          기타비유동부채  1.672645e+10
# 78789             부채총계  1.943564e+11
# 78790       자본abstract           NaN
# 78791         지배기업주주지분  7.152484e+10
# 78792              자본금  7.814027e+09
# 78793           보통주자본금  6.000000e+09
# 78794          주식발행초과금  1.814027e+09
# 78795           기타자본항목 -1.119147e+08
# 78796         해외사업환산손익 -1.119147e+08
# 78797            이익잉여금  6.382272e+10
# 78798            비지배지분  5.871859e+08
# 78799             자본총계  7.211202e+10
# 78800          자본과부채총계  2.664684e+11

# %% [markdown]
# ### 7. 정제된 데이터 프레임 만들기

# %%
# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df2019["회사명"].unique()
element_value = list(new_criterion[new_criterion["개선항목명"] != "지우기"]["개선항목명"])

# columns
col = list(df2019.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df2019[df2019["회사명"] == i]["결산기준일"].unique())
    day.append(len(df2019[df2019["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
last_df = pd.DataFrame(bon, columns = col)

# %%
last_df.head()
# Out:
#    종목코드  회사명  시장구분  업종  업종명  결산월  결산기준일  보고서종류  재무상태표 [abstract]  \
# 0   NaN  NaN   NaN NaN  NaN  NaN    NaN    NaN               NaN
# 1   NaN  NaN   NaN NaN  NaN  NaN    NaN    NaN               NaN
# 2   NaN  NaN   NaN NaN  NaN  NaN    NaN    NaN               NaN
# 3   NaN  NaN   NaN NaN  NaN  NaN    NaN    NaN               NaN
# 4   NaN  NaN   NaN NaN  NaN  NaN    NaN    NaN               NaN
#
#    자산 [abstract]  ...  퇴직급여운용자산/퇴직연금운용자산  퇴직보험예치금  이연법인세부채  기타비유동부채  비유동배출부채  \
# 0            NaN  ...                NaN      NaN      NaN      NaN      NaN
# 1            NaN  ...                NaN      NaN      NaN      NaN      NaN
# 2            NaN  ...                NaN      NaN      NaN      NaN      NaN
# 3            NaN  ...                NaN      NaN      NaN      NaN      NaN
# 4            NaN  ...                NaN      NaN      NaN      NaN      NaN
#
#    부채총계  자본 [abstract]  이익잉여금(결손금)  자본총계  자본과부채총계
# 0   NaN            NaN         NaN   NaN      NaN
# 1   NaN            NaN         NaN   NaN      NaN
# 2   NaN            NaN         NaN   NaN      NaN
# 3   NaN            NaN         NaN   NaN      NaN
# 4   NaN            NaN         NaN   NaN      NaN
#
# [5 rows x 361 columns]

# %% [markdown]
# ### 8. 데이터 입력

# %%
dic_standard = {i:list(df2019[df2019["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df2019[(df2019["회사명"] == last_company[idx]) & (df2019["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        last_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = a["항목명"][idx3]
            last_df.loc[cnt, loc] = a["당기"][idx3]
    cnt += 1

# %%
last_df
# Out:
#           종목코드     회사명        시장구분     업종                       업종명   결산월  \
# 0     [060310]      3S   코스닥시장상장법인  292.0             특수 목적용 기계 제조업   3.0
# 1     [095570]  AJ네트웍스  유가증권시장상장법인  763.0           산업용 기계 및 장비 임대업  12.0
# 2     [006840]   AK홀딩스  유가증권시장상장법인  649.0                    기타 금융업  12.0
# 3     [054620]  APS홀딩스   코스닥시장상장법인  649.0                    기타 금융업  12.0
# 4     [265520]   AP시스템   코스닥시장상장법인  292.0             특수 목적용 기계 제조업  12.0
# ...        ...     ...         ...    ...                       ...   ...
# 1687  [069260]     휴켐스  유가증권시장상장법인  204.0               기타 화학제품 제조업  12.0
# 1688  [010240]      흥국   코스닥시장상장법인  292.0             특수 목적용 기계 제조업  12.0
# 1689  [189980]  흥국에프엔비   코스닥시장상장법인  112.0           비알코올음료 및 얼음 제조업  12.0
# 1690  [003280]    흥아해운  유가증권시장상장법인  501.0                    해상 운송업  12.0
# 1691  [037440]      희림   코스닥시장상장법인  721.0  건축기술, 엔지니어링 및 관련 기술 서비스업  12.0
#
#            결산기준일  보고서종류  재무상태표 [abstract]  자산 [abstract]  ...  \
# 0     2019-03-31  사업보고서               NaN            NaN  ...
# 1     2019-12-31  사업보고서               NaN            NaN  ...
# 2     2019-12-31  사업보고서               NaN            NaN  ...
# 3     2019-12-31  사업보고서               NaN            NaN  ...
# 4     2019-12-31  사업보고서               NaN            NaN  ...
# ...          ...    ...               ...            ...  ...
# 1687  2019-12-31  사업보고서               NaN            NaN  ...
# 1688  2019-12-31  사업보고서               NaN            NaN  ...
# 1689  2019-12-31  사업보고서               NaN            NaN  ...
# 1690  2019-12-31  사업보고서               NaN            NaN  ...
# 1691  2019-12-31  사업보고서               NaN            NaN  ...
#
#       퇴직급여운용자산/퇴직연금운용자산  퇴직보험예치금       이연법인세부채       기타비유동부채  비유동배출부채  \
# 0                   NaN      NaN           NaN           NaN      NaN
# 1                   NaN      NaN  9.811366e+08  5.636559e+09      NaN
# 2                   NaN      NaN  3.628085e+10  1.021370e+10      NaN
# 3                   NaN      NaN  3.651808e+09  1.749345e+08      NaN
# 4                   NaN      NaN           NaN           NaN      NaN
# ...                 ...      ...           ...           ...      ...
# 1687       1.070385e+09      NaN  7.640479e+08  3.393428e+09      NaN
# 1688                NaN      NaN  1.727791e+09  2.130874e+08      NaN
# 1689                NaN      NaN           NaN           NaN      NaN
# 1690                NaN      NaN  5.974079e+09  8.967549e+08      NaN
# 1691                NaN      NaN           NaN           NaN      NaN
#
#               부채총계  자본 [abstract]    이익잉여금(결손금)          자본총계       자본과부채총계
# 0     1.895754e+10            NaN -3.167278e+10  3.437168e+10  5.332922e+10
# 1     1.455914e+12            NaN  1.987718e+11  3.473412e+11  1.803255e+12
# 2     2.898026e+12            NaN  4.964832e+11  1.429939e+12  4.327965e+12
# 3     8.292250e+10            NaN  7.342969e+11  2.147857e+11  2.977083e+11
# 4     3.068430e+11            NaN  4.531593e+10  1.141229e+11  4.209659e+11
# ...            ...            ...           ...           ...           ...
# 1687  2.422166e+11            NaN  4.778877e+11  6.716512e+11  9.138678e+11
# 1688  2.486927e+10            NaN  5.976915e+10  6.748899e+10  9.235827e+10
# 1689  2.523555e+10            NaN  3.565874e+10  6.406664e+10  8.930219e+10
# 1690  4.000433e+11            NaN -4.548839e+10  3.091938e+10  4.309627e+11
# 1691  1.068161e+11            NaN  4.826411e+10  5.481794e+10  1.616340e+11
#
# [1692 rows x 361 columns]

# %% [markdown]
# ### 9. 2018데이터 입력

# %%
# 2018년 변수 처리
df = pd.read_csv("./data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
    data["전기"] = data["전기"].str.replace(",", "")
    data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    data["전기"] = data["전기"].astype(np.float32)
    data["전전기"] = data["전전기"].astype(np.float32)
    return data

df = str_to_float(df)

# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("당기", axis = 1, inplace = True)
    data.drop("전전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df = delete_col(df)


# 항목명 변수 전처리
lst_idx = []
for i in range(len(df)):
    if "총계" in df["항목명"][i] and "entity" in df["항목코드"][i]:
        lst_idx.append(i)


for i in lst_idx:
    if df["항목명"][i] == '부채총계':
        df["항목코드"][i] = "ifrs-full_Liabilities"
        
    elif df["항목명"][i] == '자본과 부채의 총계':
        df["항목코드"][i] = "ifrs-full_EquityAndLiabilities"
        
    elif df["항목명"][i] == '자산총계':
        df["항목코드"][i] = "ifrs-full_Assets"
        
    else:
        df["항목코드"][i] = "ifrs-full_Equity"
        
        
for idx in range(len(df)):
    if "entity" not in df["항목코드"][idx]:
        df["항목명"][idx] = dic_element[re.findall("_\w{1,}", df["항목코드"][idx])[0].lower()][0]




# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df["회사명"].unique()
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df[df["회사명"] == i]["결산기준일"].unique())
    day.append(len(df[df["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
add_df = pd.DataFrame(bon, columns = col)


# 정제된 데이터프레임 생성
dic_standard = {i:list(df[df["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df[(df["회사명"] == last_company[idx]) & (df["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        add_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = dic_element[re.findall("_\w{1,}", a["항목코드"][idx3])[0].lower()][0]
            add_df.loc[cnt, loc] = a["전기"][idx3]
    cnt += 1

add_df["결산기준일"] = add_df["결산기준일"].str.replace("2019", "2018")

last_df = pd.concat([last_df, add_df]).reset_index(drop = True)

# %% [markdown]
# ### 10. 2017 데이터 입력

# %%
# 2017년 변수 처리
df = pd.read_csv("./data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
    data["전기"] = data["전기"].str.replace(",", "")
    data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    data["전기"] = data["전기"].astype(np.float32)
    data["전전기"] = data["전전기"].astype(np.float32)
    return data

df = str_to_float(df)

# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("당기", axis = 1, inplace = True)
    data.drop("전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df = delete_col(df)

# 항목명 변수 전처리
lst_idx = []
for i in range(len(df)):
    if "총계" in df["항목명"][i] and "entity" in df["항목코드"][i]:
        lst_idx.append(i)


for i in lst_idx:
    if df["항목명"][i] == '부채총계':
        df["항목코드"][i] = "ifrs-full_Liabilities"
        
    elif df["항목명"][i] == '자본과 부채의 총계':
        df["항목코드"][i] = "ifrs-full_EquityAndLiabilities"
        
    elif df["항목명"][i] == '자산총계':
        df["항목코드"][i] = "ifrs-full_Assets"
        
    else:
        df["항목코드"][i] = "ifrs-full_Equity"
        
        
for idx in range(len(df)):
    if "entity" not in df["항목코드"][idx]:
        df["항목명"][idx] = dic_element[re.findall("_\w{1,}", df["항목코드"][idx])[0].lower()][0]

# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df2019["회사명"].unique()
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df[df["회사명"] == i]["결산기준일"].unique())
    day.append(len(df[df["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
add_df = pd.DataFrame(bon, columns = col)


dic_standard = {i:list(df[df["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df[(df["회사명"] == last_company[idx]) & (df["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        add_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = dic_element[re.findall("_\w{1,}", a["항목코드"][idx3])[0].lower()][0]
            add_df.loc[cnt, loc] = a["전전기"][idx3]
    cnt += 1

add_df["결산기준일"] = add_df["결산기준일"].str.replace("2019", "2017")

last_df = pd.concat([last_df, add_df]).reset_index(drop = True)

# %%
last_df.to_csv("./data/2017_2019_without_entity.csv", encoding = "euc-kr", index = False)
