# %% [markdown]
# ### 1.data load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

#  data load
df2019 = pd.read_csv("./data/2019_사업보고서_01_재무상태표_연결_20200623.txt", sep = "\t", encoding = "cp949")

# %% [markdown]
# ### 2. 불필요한 변수 제거

# %%
# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("전기", axis = 1, inplace = True)
    data.drop("전전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df2019 = delete_col(df2019)

# %% [markdown]
# ### 3. 연속형변수(당기, 전기, 전전기)  dtype 변경

# %%
def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
    data["전기"] = data["전기"].str.replace(",", "")
    data["전전기"] = data["전전기"].str.replace(",", "")
    data[["당기", "전기", "전전기"]] = data[["당기", "전기", "전전기"]].astype(np.float32)
    return data

df2019 = str_to_float(df2019)

# %% [markdown]
# ### 4. 항목명 변수 처리

# %%
def duplication_check(data):
    # 항목코드 중복 확인
    entity_코드 = []
    entity_명 = []
    without_entity_코드 = []
    without_entity_명 = []

    # 각 리스트에 코드 및 코드명 append(소문자 처리)
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            entity_코드.append(data["항목코드"][idx].lower())
            entity_명.append(data["항목명"][idx].lower())
        else:
            without_entity_코드.append(data["항목코드"][idx].lower())
            without_entity_명.append(data["항목명"][idx].lower())

    # !entity 코드 딕셔너리
    dic_without_entity = {without_entity_코드[idx]:[] for idx in range(len(without_entity_코드))}

    for i, j in zip(without_entity_코드, without_entity_명):
        dic_without_entity[i].append(j)

    check_without_entity = {i:len(set(j)) for i, j in dic_without_entity.items()}
    
    # entity 코드 딕셔너리
    dic_entity = {entity_코드[idx]:[] for idx in range(len(entity_코드))}
    
    for i, j in zip(entity_코드, entity_명):
        dic_entity[i].append(j)
        
    check_entity = {i:len(set(j)) for i, j in dic_entity.items()}
    
    return entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity

entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity = duplication_check(df2019)

# %% [markdown]
# ### 5. 공시된 항목명, 항목코드 가져오기(금융감독원 재무제표 양식)

# %%
def extract_element_id(data):
    element_idx_lst_entity = []
    element_idx_lst_without_entity = []
    
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            element_idx_lst_entity.append(data["항목코드"][idx])
        else:
            element_idx_lst_without_entity.append(data["항목코드"][idx])
            
    entity = sorted(set(element_idx_lst_entity), reverse = True)
    without_entity = sorted(set(element_idx_lst_without_entity), reverse = True)
    
    return entity, without_entity

a, b = extract_element_id(df2019)
pd.Series(b).to_csv("./2019항목명.csv", encoding = "euc-kr", index = False)

elementid = pd.read_csv("./data/재무제표양식.csv", encoding = "utf-8")
# '한글 Label', 'Element ID'
df_element = elementid[['한글 Label', 'Element ID']]
df_element = df_element[df_element["Element ID"].notnull()]

df_element.columns = df_element.columns.str.replace(" ", "_")
lst_element = df_element["Element_ID"].unique()

re_lst_element = []
for i in lst_element:
    a = re.findall("_\w{1,}", i)[0].lower()
    re_lst_element.append(a)
 
dic_element = {i:[] for i in re_lst_element}
for i, j in zip(re_lst_element, df_element["한글_Label"]):
    dic_element[i].append(j)

# %% [markdown]
# ### 6. entity 제외 항목명 변수 전처리

# %%
error_idx = []
for idx in range(len(df2019)):
    try:        
        if "entity" not in df2019["항목코드"][idx]:
            df2019["항목명"][idx] = dic_element[re.findall("_\w{1,}", df2019["항목코드"][idx])[0].lower()][0]
    except Exception as e:
        error_idx.append(idx)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ### 7. 에러 항목명 전처리 ~ing
# - entity제외 에러 항목코드
#   - 'ifrs_EquityAttributableToOwnersOfParent', 'ifrs_NoncontrollingInterests',
#   - 'ifrs-full_EquityAttributableToOwnersOfParent', 'ifrs-full_NoncontrollingInterests'

# %%
# 에러 항목코드 추출
key = df2019.iloc[error_idx, :]["항목코드"].unique()
print(key)
pre_dic_error = {i:[] for i in key}

for idx in error_idx:
    pre_dic_error[df2019["항목코드"][idx]].append(df2019["항목명"][idx])
    
'''
"ifrs_EquityAttributableToOwnersOfParent"      = '   지배기업의 소유주에게 귀속되는 자본'
"ifrs_NoncontrollingInterests"                 = '   비지배지분' 
'ifrs-full_EquityAttributableToOwnersOfParent' = '   지배기업의 소유주에게 귀속되는 자본', '   지배기업의 소유지분'
'ifrs-full_NoncontrollingInterests'            = '   비지배지분'
'''
dic_without_entity["ifrs_EquityAttributableToOwnersOfParent".lower()] = ['   지배기업의 소유주에게 귀속되는 자본']
dic_without_entity["ifrs_NoncontrollingInterests".lower()] = ['   비지배지분']
dic_without_entity["ifrs-full_EquityAttributableToOwnersOfParent".lower()] = ['   지배기업의 소유주에게 귀속되는 자본']
dic_without_entity["ifrs-full_NoncontrollingInterests".lower()] = ['   비지배지분']


# 에러 변수 추가 전처리
error_idx = []
for idx in range(len(df2019)):
    try:        
        if "entity" not in df2019["항목코드"][idx]:
            df2019["항목명"][idx] = dic_element[re.findall("_\w{1,}", df2019["항목코드"][idx])[0].lower()][0]
    except Exception as e:
        error_idx.append(idx)
# Out:
# ['ifrs_EquityAttributableToOwnersOfParent' 'ifrs_NoncontrollingInterests'
#  'ifrs-full_EquityAttributableToOwnersOfParent'
#  'ifrs-full_NoncontrollingInterests']
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pd.DataFrame(dic_element, index = [0])
# Out:
#   _statementoffinancialpositionabstract _assetsabstract _currentassets  \
# 0                      재무상태표 [abstract]   자산 [abstract]           유동자산
#
#   _cashandcashequivalents _cash _cashequivalents  \
# 0                현금및현금성자산    현금            현금성자산
#
#   _governmentgrantscashandcashequivalentsgross  \
# 0                                        정부보조금
#
#   _shorttermdepositsnotclassifiedascashequivalents  \
# 0                                           단기금융상품
#
#   _tradeandothercurrentreceivables _shorttermtradereceivable  ...  \
# 0                    매출채권 및 기타유동채권                      매출채권  ...
#
#   _gainsvaluationderivativescashflowhedge  \
# 0                        현금흐름위험회피파생상품평가이익
#
#   _lossesvaluationderivativescashflowhedge  \
# 0                         현금흐름위험회피파생상품평가손실
#
#   _comprehensiveincomegainslossesequitymethodsecurities _retainedearnings  \
# 0                                        지분법기타포괄손익변동           이익잉여금(결손금)
#
#   _legalreserve _appropriatedretainedearningsotherlegalreserves  \
# 0         이익준비금                                         기타법정적립금
#
#   _voluntaryreserves  \
# 0              임의적립금
#
#   _retainedearningsbeforeappropriationsaccumulateddeficitbeforedisposition  \
# 0                                   미처분이익잉여금(미처리결손금)
#
#   _equity _equityandliabilities
# 0    자본총계               자본과부채총계
#
# [1 rows x 517 columns]

# %% [markdown]
# ### 8. 정제된 데이터 프레임 만들기

# %%
# DB 테이블에 적용할 D.F
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df2019.columns[1:9]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df2019[df2019["회사명"] == i]["결산기준일"].unique())
    day.append(len(df2019[df2019["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
last_df = pd.DataFrame(bon, columns = col)

# 회사이름 추출
lst_company = df2019["회사명"].unique()

# %%
last_df.columns
# Out:
# Index(['회사명', '시장구분', '업종', '업종명', '결산월', '결산기준일', '보고서종류', '항목코드',
#        '재무상태표 [abstract]', '자산 [abstract]',
#        ...
#        '      장기차입금', '   부채총계', '   지배기업의 소유주에게 귀속되는 자본', '      자본금',
#        '      기타불입자본', '      이익잉여금(결손금)', '      기타자본구성요소', '   비지배지분',
#        '   자본총계', '부채 및 자본 총계'],
#       dtype='object', length=566)

# %%
df2019.pivot_table(["회사명"], ["항목코드"], ["당기"])

# %%
company_dic["3S"][0]
# Out:
# array(['2019-03-31'], dtype=object)

# %%
last_dict = {i:0 for i in last_df.columns}

# %%
# cnt = 0

# for idx in range(len(lst_company)):
#     print(cnt)
a = df2019[(df2019["회사명"] == lst_company[2]) & (df2019["결산기준일"] == company_dic[lst_company[2]][0][0])]
for i in range(8):
    last_df.iloc[cnt, i] = a.iloc[0, i]

for idx3 in range(len(a)):
    if "entity" not in a["항목코드"][idx3]:
        loc = dic_element[a["항목코드"][idx3].lower()][0]
        last_df.loc[cnt, loc] = a["당기"][idx3]
#     cnt += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-351-2d5daff03ff9> in <module>
#       8
#       9 for idx3 in range(len(a)):
# ---> 10     if "entity" not in a["항목코드"][idx3]:
#      11         loc = dic_element[a["항목코드"][idx3].lower()][0]
#      12         last_df.loc[cnt, loc] = a["당기"][idx3]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
df2019[(df2019["회사명"] == lst_company[2]) & (df2019["결산기준일"] == company_dic[lst_company[2]][0][0])]
for ij in range(len(a)):
    if "entity" not in a["항목코드"][j]:
        loc = dic_element[a["항목코드"][j].lower()][0]
        last_df.loc[2, loc] = a["당기"][j]

# %%
df2019[(df2019["회사명"] == lst_company[2]) & (df2019["결산기준일"] == company_dic[lst_company[2]][0][0])]
# Out:
#          종목코드    회사명        시장구분   업종     업종명  결산월       결산기준일  보고서종류  \
# 101  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 102  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 103  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 104  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 105  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 106  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 107  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 108  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 109  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 110  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 111  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 112  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 113  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 114  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 115  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 116  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 117  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 118  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 119  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 120  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 121  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 122  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 123  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 124  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 125  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 126  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 127  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 128  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 129  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 130  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 131  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 132  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 133  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 134  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 135  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 136  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 137  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 138  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 139  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 140  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 141  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 142  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 143  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 144  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 145  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 146  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 147  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 148  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 149  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 150  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 151  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 152  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 153  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 154  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 155  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 156  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 157  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 158  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
# 159  [006840]  AK홀딩스  유가증권시장상장법인  649  기타 금융업   12  2019-12-31  사업보고서
#
#                                                   항목코드  \
# 101                           ifrs-full_AssetsAbstract
# 102                            ifrs-full_CurrentAssets
# 103                   ifrs-full_CashAndCashEquivalents
# 104                      dart_ShortTermTradeReceivable
# 105  entity00125080_udf_BS_20171110123425413_Curren...
# 106  entity00125080_udf_BS_2019329164336214_Current...
# 107  ifrs-full_CurrentFinancialAssetsMeasuredAtFair...
# 108  entity00125080_udf_BS_20171110123436780_Curren...
# 109        dart_CurrentAvailableForSaleFinancialAssets
# 110                        dart_CurrentDerivativeAsset
# 111              ifrs-full_OtherCurrentFinancialAssets
# 112                              ifrs-full_Inventories
# 113                            dart_OtherCurrentAssets
# 114  entity00125080_udf_BS_2019329164615762_Current...
# 115                         ifrs-full_NoncurrentAssets
# 116                 dart_LongTermTradeReceivablesGross
# 117  entity00125080_udf_BS_20171110123811707_Noncur...
# 118  entity00125080_udf_BS_2019329164731367_Noncurr...
# 119  ifrs-full_NoncurrentFinancialAssetsMeasuredAtF...
# 120             dart_NonCurrentFairValueFinancialAsset
# 121     dart_NonCurrentAvailableForSaleFinancialAssets
# 122                    dart_NonCurrentDerivativeAssets
# 123           ifrs-full_OtherNoncurrentFinancialAssets
# 124  ifrs-full_InvestmentsInSubsidiariesJointVentur...
# 125                ifrs-full_PropertyPlantAndEquipment
# 126                    dart_OtherIntangibleAssetsGross
# 127                       ifrs-full_InvestmentProperty
# 128                         ifrs-full_RightofuseAssets
# 129                        ifrs-full_DeferredTaxAssets
# 130                         dart_OtherNonCurrentAssets
# 131                                   ifrs-full_Assets
# 132                      ifrs-full_LiabilitiesAbstract
# 133                       ifrs-full_CurrentLiabilities
# 134                        dart_ShortTermTradePayables
# 135  entity00125080_udf_BS_20171110124140754_Curren...
# 136                      ifrs-full_ShorttermBorrowings
# 137                    ifrs-full_CurrentTaxLiabilities
# 138                  dart_CurrentDerivativeLiabilities
# 139    ifrs-full_ShorttermMiscellaneousOtherProvisions
# 140                       dart_OtherCurrentLiabilities
# 141                    ifrs-full_NoncurrentLiabilities
# 142  entity00125080_udf_BS_20171110124338106_Noncur...
# 143                       dart_LongTermBorrowingsGross
# 144               dart_NonCurrentDerivativeLiabilities
# 145              dart_PostemploymentBenefitObligations
# 146                   ifrs-full_DeferredTaxLiabilities
# 147     ifrs-full_LongtermMiscellaneousOtherProvisions
# 148                    dart_OtherNonCurrentLiabilities
# 149                              ifrs-full_Liabilities
# 150                           ifrs-full_EquityAbstract
# 151       ifrs-full_EquityAttributableToOwnersOfParent
# 152                            ifrs-full_IssuedCapital
# 153                                dart_CapitalSurplus
# 154             dart_ElementsOfOtherStockholdersEquity
# 155  dart_OtherComprehensiveIncomeLossAccumulatedAm...
# 156                         ifrs-full_RetainedEarnings
# 157                  ifrs-full_NoncontrollingInterests
# 158                                   ifrs-full_Equity
# 159                     ifrs-full_EquityAndLiabilities
#
#                             항목명            당기
# 101               자산 [abstract]           NaN
# 102                        유동자산  1.327787e+12
# 103                    현금및현금성자산  2.848855e+11
# 104                        매출채권  2.792229e+11
# 105                      기타수취채권  9.399519e+10
# 106             당기손익-공정가치측정금융자산  2.613975e+11
# 107      유동 기타포괄손익-공정가치 측정 금융자산  1.652422e+07
# 108                  당기손익인식금융자산  0.000000e+00
# 109                  유동매도가능금융자산  0.000000e+00
# 110                    유동파생상품자산  1.770314e+09
# 111                    기타유동금융자산  2.557943e+10
# 112                        재고자산  2.537150e+11
# 113                      기타유동자산  1.272042e+11
# 114                   매각예정비유동자산  0.000000e+00
# 115                       비유동자산  3.000178e+12
# 116                      장기매출채권  2.365440e+08
# 117                      기타수취채권  1.106051e+11
# 118             당기손익-공정가치측정금융자산  3.349410e+10
# 119     비유동 기타포괄손익-공정가치 측정 금융자산  3.809393e+09
# 120               비유동당기손익인식금융자산  0.000000e+00
# 121                 비유동매도가능금융자산  0.000000e+00
# 122                   비유동파생상품자산  1.704878e+09
# 123                   기타비유동금융자산  3.948646e+08
# 124  종속기업, 조인트벤처와 관계기업에 대한 투자자산  8.485386e+10
# 125                        유형자산  1.430033e+12
# 126                      기타무형자산  2.067105e+11
# 127                       투자부동산  1.175350e+11
# 128                       사용권자산  9.528195e+11
# 129                     이연법인세자산  4.933496e+10
# 130                     기타비유동자산  8.646241e+09
# 131                        자산총계  4.327965e+12
# 132               부채 [abstract]           NaN
# 133                        유동부채  1.565482e+12
# 134                      단기매입채무  3.295428e+11
# 135                      기타지급채무  2.446126e+11
# 136                       단기차입금  6.354473e+11
# 137                     당기법인세부채  2.630351e+10
# 138                    유동파생상품부채  1.032516e+09
# 139               그 밖의 기타단기충당부채  6.779196e+10
# 140                      기타유동부채  2.607509e+11
# 141                       비유동부채  1.332544e+12
# 142                    기타장기지급채무  1.007684e+11
# 143                       장기차입금  1.017137e+12
# 144                   비유동파생상품부채  1.021784e+09
# 145                      퇴직급여부채  1.888259e+10
# 146                     이연법인세부채  3.628085e+10
# 147               그 밖의 기타장기충당부채  1.482396e+11
# 148                     기타비유동부채  1.021370e+10
# 149                        부채총계  2.898026e+12
# 150               자본 [abstract]           NaN
# 151                  지배기업의 소유지분  8.272823e+11
# 152                         자본금  6.623780e+10
# 153                       자본잉여금  2.648924e+11
# 154                    기타자본구성요소 -5.581176e+09
# 155                   기타포괄손익누계액  5.250166e+09
# 156                  이익잉여금(결손금)  4.964832e+11
# 157                       비지배지분  6.026565e+11
# 158                        자본총계  1.429939e+12
# 159                     자본과부채총계  4.327965e+12

# %%
df2019[df2019["회사명"] == lst_company[0]].head(2)
# Out:
#        종목코드 회사명       시장구분   업종            업종명  결산월       결산기준일  보고서종류  \
# 0  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3  2019-03-31  사업보고서
# 1  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3  2019-03-31  사업보고서
#
#                   항목코드            항목명            당기
# 0  ifrs_AssetsAbstract  자산 [abstract]           NaN
# 1   ifrs_CurrentAssets           유동자산  1.807934e+10

# %%
last_df.head()
# Out:
#    회사명  시장구분  업종  업종명  결산월  결산기준일  보고서종류  항목코드  재무상태표 [abstract]  \
# 0  NaN   NaN NaN  NaN  NaN    NaN    NaN   NaN               NaN
# 1  NaN   NaN NaN  NaN  NaN    NaN    NaN   NaN               NaN
# 2  NaN   NaN NaN  NaN  NaN    NaN    NaN   NaN               NaN
# 3  NaN   NaN NaN  NaN  NaN    NaN    NaN   NaN               NaN
# 4  NaN   NaN NaN  NaN  NaN    NaN    NaN   NaN               NaN
#
#    자산 [abstract]  ...  현금흐름위험회피파생상품평가이익  현금흐름위험회피파생상품평가손실  지분법기타포괄손익변동  \
# 0            NaN  ...               NaN               NaN          NaN
# 1            NaN  ...               NaN               NaN          NaN
# 2            NaN  ...               NaN               NaN          NaN
# 3            NaN  ...               NaN               NaN          NaN
# 4            NaN  ...               NaN               NaN          NaN
#
#    이익잉여금(결손금)  이익준비금  기타법정적립금  임의적립금  미처분이익잉여금(미처리결손금)  자본총계  자본과부채총계
# 0         NaN    NaN      NaN    NaN               NaN   NaN      NaN
# 1         NaN    NaN      NaN    NaN               NaN   NaN      NaN
# 2         NaN    NaN      NaN    NaN               NaN   NaN      NaN
# 3         NaN    NaN      NaN    NaN               NaN   NaN      NaN
# 4         NaN    NaN      NaN    NaN               NaN   NaN      NaN
#
# [5 rows x 525 columns]

# %%
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df2019.columns[1:9]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df2019[df2019["회사명"] == i]["결산기준일"].unique())
    day.append(len(df2019[df2019["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F


# 회사이름 추출
lst_company = df2019["회사명"].unique()

# %%
print(len(col))
print(len(last_df.columns))
# Out:
# 525
# 566

# %%
len(element_value)
# Out:
# 517

# %%
last_df = pd.DataFrame(bon, columns = col)

# %%
last_df.columns
# Out:
# Index(['회사명', '시장구분', '업종', '업종명', '결산월', '결산기준일', '보고서종류', '항목코드',
#        '재무상태표 [abstract]', '자산 [abstract]',
#        ...
#        '현금흐름위험회피파생상품평가이익', '현금흐름위험회피파생상품평가손실', '지분법기타포괄손익변동', '이익잉여금(결손금)',
#        '이익준비금', '기타법정적립금', '임의적립금', '미처분이익잉여금(미처리결손금)', '자본총계', '자본과부채총계'],
#       dtype='object', length=525)
