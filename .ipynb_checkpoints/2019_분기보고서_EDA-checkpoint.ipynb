# %% [markdown]
# ### 1. data load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
#  data load
df = pd.read_csv("./data/2019_반기보고서_01_재무상태표_연결_20200627.txt", sep = "\t", encoding = "cp949")

# %% [markdown]
# ### 2. 연속형변수 변경 dtype 변경

# %%
def str_to_float(data):
    import numpy as np
    
    data["당기 반기말"] = data["당기 반기말"].str.replace(",", "")
    data["전기말"] = data["전기말"].str.replace(",", "")
#     data["전전기말"] = data["전전기말"].str.replace(",", "")
    data["당기 반기말"] = data["당기 반기말"].astype(np.float32)
    return data

df = str_to_float(df)

# %% [markdown]
# ### 3. 불필요한 변수 제거

# %%
# 필요 없는 변수 제거
def delete_col(data):
#     data.drop("통화", axis = 1, inplace = True)
#     data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("전기말", axis = 1, inplace = True)
    data.drop("전전기말", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df = delete_col(df)

# %% [markdown]
# ### 4. 항목명 변수 처리

# %%
def duplication_check(data):
    # 항목코드 중복 확인
    entity_코드 = []
    entity_명 = []
    without_entity_코드 = []
    without_entity_명 = []

    # 각 리스트에 코드 및 코드명 append(소문자 처리)
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            entity_코드.append(data["항목코드"][idx].lower())
            entity_명.append(data["항목명"][idx].lower())
        else:
            without_entity_코드.append(data["항목코드"][idx].lower())
            without_entity_명.append(data["항목명"][idx].lower())

    # !entity 코드 딕셔너리
    dic_without_entity = {re.findall("_\w{1,}", without_entity_코드[idx])[0].lower():[] for idx in range(len(without_entity_코드))}

    for i, j in zip(without_entity_코드, without_entity_명):
        dic_without_entity[re.findall("_\w{1,}", i)[0].lower()].append(j)

    check_without_entity = {i:len(set(j)) for i, j in dic_without_entity.items()}
    
    # entity 코드 딕셔너리
    dic_entity = {entity_코드[idx]:[] for idx in range(len(entity_코드))}
    
    for i, j in zip(entity_코드, entity_명):
        dic_entity[i].append(j)
        
    check_entity = {i:len(set(j)) for i, j in dic_entity.items()}
    
    return entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity

entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity = duplication_check(df)

# %% [markdown]
# ### 5. 공시된 항목명, 항목코드 가져오기(금융감독원 재무제표 양식)

# %%
def extract_element_id(data):
    element_idx_lst_entity = []
    element_idx_lst_without_entity = []
    
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            element_idx_lst_entity.append(data["항목코드"][idx])
        else:
            element_idx_lst_without_entity.append(data["항목코드"][idx])
            
    entity = sorted(set(element_idx_lst_entity), reverse = True)
    without_entity = sorted(set(element_idx_lst_without_entity), reverse = True)
    
    return entity, without_entity

a, b = extract_element_id(df)

elementid = pd.read_excel("./data/재무제표양식.xlsx", encoding = "utf-8", sheet_name = "BS1")
# '한글 Label', 'Element ID'
df_element = elementid[['한글 Label', 'Element ID']]
df_element = df_element[df_element["Element ID"].notnull()]

df_element.columns = df_element.columns.str.replace(" ", "_")
lst_element = df_element["Element_ID"].unique()

re_lst_element = []
for i in lst_element:
    a = re.findall("_\w{1,}", i)[0].lower()
    re_lst_element.append(a)
 
dic_element = {i:[] for i in re_lst_element}
for i, j in zip(re_lst_element, df_element["한글_Label"]):
    dic_element[i].append(j)

# %% [markdown]
# ### 6. entity 제외 항목명 변수 전처리

# %%
lst_idx = []
for idx in range(len(df)):
    try:
        if "entity" not in df["항목코드"][idx]:
            df["항목명"][idx] = dic_element[re.findall("_\w{1,}", df["항목코드"][idx])[0].lower()][0]
    except Exception as e:
        lst_idx.append(idx)
# Out:
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ### 7. 정제된 데이터 프레임 만들기

# %%
df.head()
# Out:
#        종목코드 회사명       시장구분   업종            업종명  결산월       결산기준일  보고서종류  \
# 0  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3  2019-09-30  반기보고서
# 1  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3  2019-09-30  반기보고서
# 2  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3  2019-09-30  반기보고서
# 3  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3  2019-09-30  반기보고서
# 4  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3  2019-09-30  반기보고서
#
#                                                 항목코드            항목명  \
# 0                           ifrs-full_AssetsAbstract  자산 [abstract]
# 1                            ifrs-full_CurrentAssets           유동자산
# 2                   ifrs-full_CashAndCashEquivalents       현금및현금성자산
# 3  dart_ShortTermDepositsNotClassifiedAsCashEquiv...         단기금융상품
# 4          ifrs-full_TradeAndOtherCurrentReceivables  매출채권 및 기타유동채권
#
#          당기 반기말
# 0           NaN
# 1  1.709275e+10
# 2  8.833444e+09
# 3  6.114115e+07
# 4  2.232528e+09

# %%
# DB 테이블에 적용할 D.F
# 회사이름 추출
lst_company = df["회사명"].unique()
element_value = []
for i in dic_element.values():
    element_value.append(i[0])
    
# columns
col = list(df.columns[0:8]) + element_value
check_col = list(dic_element.keys())

#  해당년도 데이터 행길이
company_dic = {i:[] for i in lst_company}
day = []

for i in lst_company:
    company_dic[i].append(df[df["회사명"] == i]["결산기준일"].unique())
    day.append(len(df[df["회사명"] == i]["결산기준일"].unique()))
    
row = sum(day)

bon = np.zeros([row,len(col)]) + np.NAN

# D.F
last_df = pd.DataFrame(bon, columns = col)

# %% [markdown]
# ### 8. 데이터 입력

# %%
dic_standard = {i:list(df[df["회사명"] == i]["결산기준일"].unique()) for i in lst_company}
last_company = []
last_standard  = []
for key, value in dic_standard.items():
    for index in range(len(value)):
        last_company.append(key)
        last_standard.append(value[index])
        
cnt = 0

for idx in range(len(last_company)):

    a = df[(df["회사명"] == last_company[idx]) & (df["결산기준일"] == last_standard[idx])]
    a.reset_index(drop = True, inplace = True)
    for i in range(8):
        last_df.iloc[cnt, i] = a.iloc[0, i]

    for idx3 in range(len(a)):
        if "entity" not in a["항목코드"][idx3]:
            loc = dic_element[re.findall("_\w{1,}", a["항목코드"][idx3])[0].lower()][0]
            last_df.loc[cnt, loc] = a["당기 반기말"][idx3]
    cnt += 1

# %%
df2019 = pd.read_csv("./data/2017_2019_without_entity.csv", encoding = "euc-kr")

# %%
col2019 = df2019.columns
col = last_df.columns

for i, j in zip(col2019, col):
    if i != j:
        print(i, j)

last_df.columns = col2019
# Out:
# 대손충당금.1 대손충당금
# 대손충당금.2 대손충당금
# 대손충당금.3 대손충당금
# 대손충당금.4 대손충당금
# 대손충당금.5 대손충당금
# 대손충당금.6 대손충당금
# 대손충당금.7 대손충당금
# 대손충당금.8 대손충당금
# 대손충당금.9 대손충당금
# 대손충당금.10 대손충당금
# 대손충당금.11 대손충당금
# 대손충당금.12 대손충당금
# 대손충당금.13 대손충당금
# 대손충당금.14 대손충당금
# 평가충당금.1 평가충당금
# 평가충당금.2 평가충당금
# 평가충당금.3 평가충당금
# 평가충당금.4 평가충당금
# 평가충당금.5 평가충당금
# 평가충당금.6 평가충당금
# 평가충당금.7 평가충당금
# 평가충당금.8 평가충당금
# 평가충당금.9 평가충당금
# 평가충당금.10 평가충당금
# 평가충당금.11 평가충당금
# 평가충당금.12 평가충당금
# 정부보조금.1 정부보조금
# 정부보조금.2 정부보조금
# 손상차손누계액.1 손상차손누계액
# 대손충당금.15 대손충당금
# 현재가치할인차금.1 현재가치할인차금
# 대손충당금.16 대손충당금
# 현재가치할인차금.2 현재가치할인차금
# 대손충당금.17 대손충당금
# 현재가치할인차금.3 현재가치할인차금
# 대손충당금.18 대손충당금
# 현재가치할인차금.4 현재가치할인차금
# 대손충당금.19 대손충당금
# 현재가치할인차금.5 현재가치할인차금
# 대손충당금.20 대손충당금
# 현재가치할인차금.6 현재가치할인차금
# 대손충당금.21 대손충당금
# 현재가치할인차금.7 현재가치할인차금
# 대손충당금.22 대손충당금
# 현재가치할인차금.8 현재가치할인차금
# 대손충당금.23 대손충당금
# 현재가치할인차금.9 현재가치할인차금
# 대손충당금.24 대손충당금
# 현재가치할인차금.10 현재가치할인차금
# 대손충당금.25 대손충당금
# 현재가치할인차금.11 현재가치할인차금
# 대손충당금.26 대손충당금
# 현재가치할인차금.12 현재가치할인차금
# 대손충당금.27 대손충당금
# 현재가치할인차금.13 현재가치할인차금
# 대손충당금.28 대손충당금
# 현재가치할인차금.14 현재가치할인차금
# 대손충당금.29 대손충당금
# 정부보조금.3 정부보조금
# 손상차손누계액.2 손상차손누계액
# 정부보조금.4 정부보조금
# 감가상각누계액.1 감가상각누계액
# 손상차손누계액.3 손상차손누계액
# 정부보조금.5 정부보조금
# 감가상각누계액.2 감가상각누계액
# 손상차손누계액.4 손상차손누계액
# 정부보조금.6 정부보조금
# 감가상각누계액.3 감가상각누계액
# 손상차손누계액.5 손상차손누계액
# 정부보조금.7 정부보조금
# 감가상각누계액.4 감가상각누계액
# 손상차손누계액.6 손상차손누계액
# 정부보조금.8 정부보조금
# 감가상각누계액.5 감가상각누계액
# 손상차손누계액.7 손상차손누계액
# 정부보조금.9 정부보조금
# 감가상각누계액.6 감가상각누계액
# 손상차손누계액.8 손상차손누계액
# 정부보조금.10 정부보조금
# 감가상각누계액.7 감가상각누계액
# 손상차손누계액.9 손상차손누계액
# 정부보조금.11 정부보조금
# 감가상각누계액.8 감가상각누계액
# 손상차손누계액.10 손상차손누계액
# 정부보조금.12 정부보조금
# 감가상각누계액.9 감가상각누계액
# 손상차손누계액.11 손상차손누계액
# 정부보조금.13 정부보조금
# 감가상각누계액.10 감가상각누계액
# 손상차손누계액.12 손상차손누계액
# 정부보조금.14 정부보조금
# 감가상각누계액.11 감가상각누계액
# 손상차손누계액.13 손상차손누계액
# 정부보조금.15 정부보조금
# 감가상각누계액.12 감가상각누계액
# 손상차손누계액.14 손상차손누계액
# 정부보조금.16 정부보조금
# 감가상각누계액.13 감가상각누계액
# 손상차손누계액.15 손상차손누계액
# 정부보조금.17 정부보조금
# 감가상각누계액.14 감가상각누계액
# 손상차손누계액.16 손상차손누계액
# 정부보조금.18 정부보조금
# 손상차손누계액.17 손상차손누계액
# 정부보조금.19 정부보조금
# 감가상각누계액.15 감가상각누계액
# 손상차손누계액.18 손상차손누계액
# 정부보조금.20 정부보조금
# 감가상각누계액.16 감가상각누계액
# 손상차손누계액.19 손상차손누계액
# 정부보조금.21 정부보조금
# 감가상각누계액.17 감가상각누계액
# 손상차손누계액.20 손상차손누계액
# 정부보조금.22 정부보조금
# 감가상각누계액.18 감가상각누계액
# 손상차손누계액.21 손상차손누계액
# 손상차손누계액.22 손상차손누계액
# 정부보조금.23 정부보조금
# 감가상각누계액.19 감가상각누계액
# 손상차손누계액.23 손상차손누계액
# 정부보조금.24 정부보조금
# 감가상각누계액.20 감가상각누계액
# 손상차손누계액.24 손상차손누계액
# 정부보조금.25 정부보조금
# 감가상각누계액.21 감가상각누계액
# 손상차손누계액.25 손상차손누계액
# 정부보조금.26 정부보조금
# 감가상각누계액.22 감가상각누계액
# 손상차손누계액.26 손상차손누계액
# 정부보조금.27 정부보조금
# 감가상각누계액.23 감가상각누계액
# 손상차손누계액.27 손상차손누계액
# 정부보조금.28 정부보조금
# 감가상각누계액.24 감가상각누계액
# 손상차손누계액.28 손상차손누계액
# 정부보조금.29 정부보조금
# 감가상각누계액.25 감가상각누계액
# 손상차손누계액.29 손상차손누계액
# 정부보조금.30 정부보조금
# 감가상각누계액.26 감가상각누계액
# 손상차손누계액.30 손상차손누계액
# 정부보조금.31 정부보조금
# 감가상각누계액.27 감가상각누계액
# 손상차손누계액.31 손상차손누계액
# 정부보조금.32 정부보조금
# 감가상각누계액.28 감가상각누계액
# 손상차손누계액.32 손상차손누계액
# 정부보조금.33 정부보조금
# 감가상각누계액.29 감가상각누계액
# 손상차손누계액.33 손상차손누계액
# 정부보조금.34 정부보조금
# 감가상각누계액.30 감가상각누계액
# 손상차손누계액.34 손상차손누계액
# 정부보조금.35 정부보조금
# 감가상각누계액.31 감가상각누계액
# 손상차손누계액.35 손상차손누계액
# 정부보조금.36 정부보조금
# 감가상각누계액.32 감가상각누계액
# 손상차손누계액.36 손상차손누계액
# 정부보조금.37 정부보조금
# 감가상각누계액.33 감가상각누계액
# 손상차손누계액.37 손상차손누계액
# 정부보조금.38 정부보조금
# 감가상각누계액.34 감가상각누계액
# 손상차손누계액.38 손상차손누계액
# 정부보조금.39 정부보조금
# 손상차손누계액.39 손상차손누계액
# 정부보조금.40 정부보조금
# 손상차손누계액.40 손상차손누계액
# 정부보조금.41 정부보조금
# 감가상각누계액.35 감가상각누계액
# 손상차손누계액.41 손상차손누계액
# 정부보조금.42 정부보조금
# 감가상각누계액.36 감가상각누계액
# 손상차손누계액.42 손상차손누계액
# 현재가치할인차금.15 현재가치할인차금
# 현재가치할인차금.16 현재가치할인차금
# 현재가치할인차금.17 현재가치할인차금
# 현재가치할인차금.18 현재가치할인차금
# 현재가치할인차금.19 현재가치할인차금
# 현재가치할인차금.20 현재가치할인차금
# 현재가치할인차금.21 현재가치할인차금
# 현재가치할인차금.22 현재가치할인차금
# 현재가치할인차금.23 현재가치할인차금
# 현재가치할인차금.24 현재가치할인차금
# 현재가치할인차금.25 현재가치할인차금
# 현재가치할인차금.26 현재가치할인차금
# 퇴직급여운용자산/퇴직연금운용자산.1 퇴직급여운용자산/퇴직연금운용자산
# 퇴직보험예치금.1 퇴직보험예치금

# %%
real_df = pd.concat([df2019, last_df]).reset_index(drop = True)

# %%
real_df.to_csv("./data/분기_반기.csv", encoding = "euc=kr", index = False)
