# %% [markdown]
# ### 1. data load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

#  data load
df2017 = pd.read_csv("./data/2017_사업보고서_01_재무상태표_연결_20200626.txt", sep = "\t", encoding = "cp949")

# %% [markdown]
# ### 2. 연속형변수 변경 dtype 변경

# %%
def str_to_float(data):
    import numpy as np
    
    data["당기"] = data["당기"].str.replace(",", "")
    data["전기"] = data["전기"].str.replace(",", "")
    data["전전기"] = data["전전기"].str.replace(",", "")
    data["당기"] = data["당기"].astype(np.float32)
    return data

df2017 = str_to_float(df2017)

# %% [markdown]
# ### 3. 불필요한 변수 제거

# %%
# 필요 없는 변수 제거
def delete_col(data):
    data.drop("통화", axis = 1, inplace = True)
    data.drop("Unnamed: 15", axis = 1, inplace = True)
    data.drop("당기", axis = 1, inplace = True)
    data.drop("전전기", axis = 1, inplace = True)
    data.drop("재무제표종류", axis = 1, inplace = True)
    return data

df2017 = delete_col(df2017)

# %% [markdown]
# ### 4. 항목명 변수 처리

# %%
def duplication_check(data):
    # 항목코드 중복 확인
    entity_코드 = []
    entity_명 = []
    without_entity_코드 = []
    without_entity_명 = []

    # 각 리스트에 코드 및 코드명 append(소문자 처리)
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            entity_코드.append(data["항목코드"][idx].lower())
            entity_명.append(data["항목명"][idx].lower())
        else:
            without_entity_코드.append(data["항목코드"][idx].lower())
            without_entity_명.append(data["항목명"][idx].lower())

    # !entity 코드 딕셔너리
    dic_without_entity = {re.findall("_\w{1,}", without_entity_코드[idx])[0].lower():[] for idx in range(len(without_entity_코드))}

    for i, j in zip(without_entity_코드, without_entity_명):
        dic_without_entity[re.findall("_\w{1,}", i)[0].lower()].append(j)

    check_without_entity = {i:len(set(j)) for i, j in dic_without_entity.items()}
    
    # entity 코드 딕셔너리
    dic_entity = {entity_코드[idx]:[] for idx in range(len(entity_코드))}
    
    for i, j in zip(entity_코드, entity_명):
        dic_entity[i].append(j)
        
    check_entity = {i:len(set(j)) for i, j in dic_entity.items()}
    
    return entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity

entity_코드, entity_명, without_entity_코드, without_entity_명, dic_without_entity, dic_entity = duplication_check(df2017)

# %% [markdown]
# ### 5. 공시된 항목명, 항목코드 가져오기(금융감독원 재무제표 양식)

# %%
def extract_element_id(data):
    element_idx_lst_entity = []
    element_idx_lst_without_entity = []
    
    for idx in range(len(data)):
        if "entity" in data["항목코드"][idx]:
            element_idx_lst_entity.append(data["항목코드"][idx])
        else:
            element_idx_lst_without_entity.append(data["항목코드"][idx])
            
    entity = sorted(set(element_idx_lst_entity), reverse = True)
    without_entity = sorted(set(element_idx_lst_without_entity), reverse = True)
    
    return entity, without_entity

a, b = extract_element_id(df2017)

elementid = pd.read_excel("./data/재무제표양식.xlsx", encoding = "utf-8", sheet_name = "BS1")
# '한글 Label', 'Element ID'
df_element = elementid[['한글 Label', 'Element ID']]
df_element = df_element[df_element["Element ID"].notnull()]

df_element.columns = df_element.columns.str.replace(" ", "_")
lst_element = df_element["Element_ID"].unique()

re_lst_element = []
for i in lst_element:
    a = re.findall("_\w{1,}", i)[0].lower()
    re_lst_element.append(a)
 
dic_element = {i:[] for i in re_lst_element}
for i, j in zip(re_lst_element, df_element["한글_Label"]):
    dic_element[i].append(j)

# %% [markdown]
# ### 6. entity 제외 항목명 변수 전처리

# %%
lst_idx = []
for idx in range(len(df2017)):
    try:
        if "entity" not in df2017["항목코드"][idx]:
            df2017["항목명"][idx] = dic_element[re.findall("_\w{1,}", df2017["항목코드"][idx])[0].lower()][0]
    except Exception as e:
        lst_idx.append(idx)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df2017.iloc[lst_idx, :]["항목명"].unique()
# Out:
# array(['   납입자본', '      기타비유동자산', '      기타유동자산', '      기타유동부채',
#        '      기타비유동비금융자산', '   자본금', '      기타비유동부채', '      기타채권',
#        '      기타비유동비금융부채', '      기타유동비금융자산', '      기타유동비금융부채',
#        '      기타비유동채권', '      기타자본', '      단기매도가능증권', '      비유동채권',
#        '      기타지급채무', '      당기손익인식금융자산', '      매도가능금융자산',
#        '      비유동기타채권', '      기타금융부채',
#        '         매각예정으로 분류된 비유동자산이나 처분자산집단',
#        '         소유주에 대한 분배예정으로 분류된 비유동자산이나 처분자산집단', '         기타단기충당부채',
#        '      기타유동채무'], dtype=object)

# %%
df2017.iloc[lst_idx, :]["항목코드"].unique()
# Out:
# array(['dart_ContributedEquity', 'ifrs_OtherNoncurrentNonfinancialAssets',
#        'ifrs_OtherCurrentNonfinancialAssets',
#        'ifrs_OtherCurrentNonfinancialLiabilities',
#        'ifrs_NoncurrentPayables',
#        'ifrs_OtherNoncurrentNonfinancialLiabilities',
#        'dart_NonCurrentReceivablesGross', 'ifrs_OtherEquityInterest',
#        'ifrs_NoncurrentAssetsOrDisposalGroupsClassifiedAsHeldForSale',
#        'ifrs_NoncurrentAssetsOrDisposalGroupsClassifiedAsHeldForDistributionToOwners',
#        'ifrs_OtherShorttermProvisions'], dtype=object)

# %%
df2017.iloc[lst_idx, :][["회사명", "항목명", "항목코드"]]
# Out:
#           회사명                                         항목명  \
# 37         3S                                        납입자본
# 4820   SBI액시즈                                     기타비유동자산
# 4826   SBI액시즈                                      기타유동자산
# 4840   SBI액시즈                                      기타유동부채
# 4843   SBI액시즈                                        납입자본
# ...       ...                                         ...
# 72260   형지엘리트           소유주에 대한 분배예정으로 분류된 비유동자산이나 처분자산집단
# 72283   형지엘리트                                    기타단기충당부채
# 73120   효성오앤비                                      기타유동자산
# 73134   효성오앤비                                      기타유동채무
# 73141   효성오앤비                                         자본금
#
#                                                     항목코드
# 37                                dart_ContributedEquity
# 4820              ifrs_OtherNoncurrentNonfinancialAssets
# 4826                 ifrs_OtherCurrentNonfinancialAssets
# 4840            ifrs_OtherCurrentNonfinancialLiabilities
# 4843                              dart_ContributedEquity
# ...                                                  ...
# 72260  ifrs_NoncurrentAssetsOrDisposalGroupsClassifie...
# 72283                      ifrs_OtherShorttermProvisions
# 73120                ifrs_OtherCurrentNonfinancialAssets
# 73134           ifrs_OtherCurrentNonfinancialLiabilities
# 73141                             dart_ContributedEquity
#
# [76 rows x 3 columns]

# %%
df2017.to_csv("./data/2017_2017변수확인.csv", encoding = "euc-kr", index = False)

# %%
df

# %%
# Out:
#                    재무제표종류      종목코드 회사명       시장구분   업종            업종명  결산월  \
# 0   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 1   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 2   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 3   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 4   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 5   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 6   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 7   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 8   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 9   재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 10  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 11  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 12  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 13  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 14  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 15  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 16  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 17  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 18  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 19  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 20  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 21  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 22  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 23  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 24  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 25  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 26  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 27  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 28  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 29  재무상태표, 유동/비유동법-연결재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
#
#          결산기준일  보고서종류   통화                                               항목코드  \
# 0   2018-03-31  사업보고서  KRW                                ifrs_AssetsAbstract
# 1   2018-03-31  사업보고서  KRW                                 ifrs_CurrentAssets
# 2   2018-03-31  사업보고서  KRW                        ifrs_CashAndCashEquivalents
# 3   2018-03-31  사업보고서  KRW  dart_ShortTermDepositsNotClassifiedAsCashEquiv...
# 4   2018-03-31  사업보고서  KRW               ifrs_TradeAndOtherCurrentReceivables
# 5   2018-03-31  사업보고서  KRW      dart_ShortTermDueFromCustomersForContractWork
# 6   2018-03-31  사업보고서  KRW                                   ifrs_Inventories
# 7   2018-03-31  사업보고서  KRW                              ifrs_CurrentTaxAssets
# 8   2018-03-31  사업보고서  KRW                            dart_OtherCurrentAssets
# 9   2018-03-31  사업보고서  KRW                        dart_CurrentDerivativeAsset
# 10  2018-03-31  사업보고서  KRW                              ifrs_NoncurrentAssets
# 11  2018-03-31  사업보고서  KRW  dart_LongTermTradeAndOtherNonCurrentReceivable...
# 12  2018-03-31  사업보고서  KRW  dart_LongTermDepositsNotClassifiedAsCashEquiva...
# 13  2018-03-31  사업보고서  KRW     dart_NonCurrentAvailableForSaleFinancialAssets
# 14  2018-03-31  사업보고서  KRW  ifrs_InvestmentsInSubsidiariesJointVenturesAnd...
# 15  2018-03-31  사업보고서  KRW                     ifrs_PropertyPlantAndEquipment
# 16  2018-03-31  사업보고서  KRW                            ifrs_InvestmentProperty
# 17  2018-03-31  사업보고서  KRW             ifrs_IntangibleAssetsOtherThanGoodwill
# 18  2018-03-31  사업보고서  KRW                         dart_OtherNonCurrentAssets
# 19  2018-03-31  사업보고서  KRW                                        ifrs_Assets
# 20  2018-03-31  사업보고서  KRW                           ifrs_LiabilitiesAbstract
# 21  2018-03-31  사업보고서  KRW                            ifrs_CurrentLiabilities
# 22  2018-03-31  사업보고서  KRW                  ifrs_TradeAndOtherCurrentPayables
# 23  2018-03-31  사업보고서  KRW        dart_ShortTermDueToCustomersForContractWork
# 24  2018-03-31  사업보고서  KRW                           ifrs_ShorttermBorrowings
# 25  2018-03-31  사업보고서  KRW            ifrs_CurrentPortionOfLongtermBorrowings
# 26  2018-03-31  사업보고서  KRW        dart_CurentPortionOfFinanceLeaseLiabilities
# 27  2018-03-31  사업보고서  KRW    dart_CurrentProvisionsForConstructionWarranties
# 28  2018-03-31  사업보고서  KRW                       dart_OtherCurrentLiabilities
# 29  2018-03-31  사업보고서  KRW                         ifrs_CurrentTaxLiabilities
#
#                    항목명              당기              전기             전전기  \
# 0        자산 [abstract]             NaN             NaN             NaN
# 1                 유동자산  12,801,669,723  16,712,868,726  13,426,668,881
# 2             현금및현금성자산   3,334,592,609   1,907,555,885   1,162,377,195
# 3               단기금융상품     866,906,654   1,458,454,774   1,137,287,724
# 4            매출채권및기타채권   3,818,198,582   7,668,857,700   8,033,600,640
# 5                미청구공사   2,730,789,484   2,382,884,896   1,432,899,484
# 6                 재고자산   1,622,662,496   1,951,967,109   1,328,408,087
# 7              당기법인세자산       4,430,210       5,280,180       4,658,572
# 8               기타유동자산     424,089,688   1,232,988,422     327,437,179
# 9               파생금융상품             NaN     104,879,760             NaN
# 10               비유동자산  36,719,329,336  36,994,034,971  44,319,720,315
# 11        장기성매출채권및기타채권     311,077,524     402,431,734     323,760,302
# 12              장기금융상품     465,860,000     290,860,000     512,876,925
# 13            매도가능금융자산   2,728,990,673   2,574,564,271   2,876,922,411
# 14            관계기업투자자산     817,545,870             NaN             NaN
# 15                유형자산  29,530,491,989  30,512,675,144  37,130,483,135
# 16               투자부동산   1,440,712,907   1,465,127,139   1,489,541,371
# 17                무형자산   1,391,927,246   1,706,561,227   1,929,023,051
# 18             기타비유동자산      32,723,127      41,815,456      57,113,120
# 19                자산총계  49,520,999,059  53,706,903,697  57,746,389,196
# 20       부채 [abstract]             NaN             NaN             NaN
# 21                유동부채  12,539,083,622  15,356,228,050  16,138,353,743
# 22           매입채무및기타채무   2,132,046,199   2,773,485,263   3,501,088,797
# 23              초과청구공사   1,063,870,596   1,233,425,770     760,564,537
# 24               단기차입금   8,264,459,082   9,721,659,082   9,761,247,000
# 25             유동성장기부채     771,800,000     759,400,000   1,509,400,000
# 26              금융리스부채             NaN             NaN     209,100,877
# 27            하자보수충당부채     201,094,316     154,819,063      74,638,249
# 28              기타유동부채      32,781,160     683,669,474      14,005,960
# 29             당기법인세부채      73,032,269      29,769,398     308,308,323
#
#     Unnamed: 15
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN

# %%
df = pd.read_csv("./data/2016_사업보고서_01_재무상태표_연결_20200626.txt", sep = "\t", encoding = "cp949")
df.iloc[37,:]
# Out:
# 재무제표종류          재무상태표, 유동/비유동법-연결재무제표
# 종목코드                         [060310]
# 회사명                                3S
# 시장구분                        코스닥시장상장법인
# 업종                                262
# 업종명                          전자부품 제조업
# 결산월                                 3
# 결산기준일                      2016-03-31
# 보고서종류                           사업보고서
# 통화                                KRW
# 항목코드           dart_ContributedEquity
# 항목명                              납입자본
# 당기                     20,446,134,000
# 전기                     20,446,134,000
# 전전기                    20,446,134,000
# Unnamed: 15                       NaN
# Name: 37, dtype: object

# %%
df = pd.read_csv("./data/2017_사업보고서_01_재무상태표_연결_20200626.txt", sep = "\t", encoding = "cp949")
df.iloc[37,:]
# Out:
# 재무제표종류          재무상태표, 유동/비유동법-연결재무제표
# 종목코드                         [060310]
# 회사명                                3S
# 시장구분                        코스닥시장상장법인
# 업종                                262
# 업종명                          전자부품 제조업
# 결산월                                 3
# 결산기준일                      2017-03-31
# 보고서종류                           사업보고서
# 통화                                KRW
# 항목코드           dart_ContributedEquity
# 항목명                              납입자본
# 당기                     20,987,069,000
# 전기                     20,446,134,000
# 전전기                    20,446,134,000
# Unnamed: 15                       NaN
# Name: 37, dtype: object

# %%
df = pd.read_csv("./data/2018_사업보고서_01_재무상태표_연결_20200627.txt", sep = "\t", encoding = "cp949")
df.iloc[37,:]
# Out:
# 재무제표종류         재무상태표, 유동/비유동법-연결재무제표
# 종목코드                        [060310]
# 회사명                               3S
# 시장구분                       코스닥시장상장법인
# 업종                               292
# 업종명                    특수 목적용 기계 제조업
# 결산월                                3
# 결산기준일                     2018-03-31
# 보고서종류                          사업보고서
# 통화                               KRW
# 항목코드              ifrs_IssuedCapital
# 항목명                              자본금
# 당기                    21,833,121,000
# 전기                    20,987,069,000
# 전전기                   20,446,134,000
# Unnamed: 15                      NaN
# Name: 37, dtype: object
